# %% [markdown]
# <a href="https://colab.research.google.com/github/younggon2/Education-ComputerVision-DeepLearning/blob/master/Day2_2%20CNN%20(Segmentation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Semantic Segmentation
#
# 이미지 내에서 픽셀 단위로 객체를 분류해내는 작업을 말합니다. 여기서 객체란 Object 즉, 사람, 자동차, 나무, 자전거 등을 말하며 Deep learning 에서는 이를 class 라고 표현합니다.
# ### ref: https://junstar92.tistory.com/150, https://m.blog.naver.com/PostView.nhn?blogId=mincheol9166&logNo=221736294296&navType=tl
#
# ![대체 텍스트](https://miro.medium.com/max/700/1*8Nwk_IdGpe235Nsfewpucg.png)
#
# from Fei-Fei Li Stanford Course — Detection And Segmentation

# %% [markdown]
# ## STEP 1: 데이터셋과 읽어들이기
# https://www.kaggle.com/nikhilpandey360/lung-segmentation-from-chest-x-ray-dataset
#
# ![대체 텍스트](https://www.altoros.com/blog/wp-content/uploads/2018/12/segmentation-results-max-dice-score.png)
#
# **Lung_Segmentation.zip**
# **256x256x3**
# **566 [image, label]**

# %%
# !wget https://github.com/younggon2/Education-ComputerVision-DeepLearning/raw/master/res/Lung_Segmentation.zip
# Out:
# --2021-05-31 00:34:42--  https://github.com/younggon2/Education-ComputerVision-DeepLearning/raw/master/res/Lung_Segmentation.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/younggon2/Education-ComputerVision-DeepLearning/master/res/Lung_Segmentation.zip [following]
# --2021-05-31 00:34:42--  https://media.githubusercontent.com/media/younggon2/Education-ComputerVision-DeepLearning/master/res/Lung_Segmentation.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56097894 (53M) [application/zip]
# Saving to: ‘Lung_Segmentation.zip’
#
# Lung_Segmentation.z 100%[===================>]  53.50M   232MB/s    in 0.2s
#
# 2021-05-31 00:34:43 (232 MB/s) - ‘Lung_Segmentation.zip’ saved [56097894/56097894]

# %%
# !unzip Lung_Segmentation.zip
# Out:
# Archive:  Lung_Segmentation.zip
#   inflating: image/resize_CHNCXR_0001_0.png
#   inflating: image/resize_CHNCXR_0002_0.png
#   inflating: image/resize_CHNCXR_0003_0.png
#   inflating: image/resize_CHNCXR_0004_0.png
#   inflating: image/resize_CHNCXR_0005_0.png
#   inflating: image/resize_CHNCXR_0006_0.png
#   inflating: image/resize_CHNCXR_0007_0.png
#   inflating: image/resize_CHNCXR_0008_0.png
#   inflating: image/resize_CHNCXR_0009_0.png
#   inflating: image/resize_CHNCXR_0010_0.png
#   inflating: image/resize_CHNCXR_0011_0.png
#   inflating: image/resize_CHNCXR_0012_0.png
#   inflating: image/resize_CHNCXR_0013_0.png
#   inflating: image/resize_CHNCXR_0014_0.png
#   inflating: image/resize_CHNCXR_0015_0.png
#   inflating: image/resize_CHNCXR_0016_0.png
#   inflating: image/resize_CHNCXR_0017_0.png
#   inflating: image/resize_CHNCXR_0018_0.png
#   inflating: image/resize_CHNCXR_0019_0.png
#   inflating: image/resize_CHNCXR_0020_0.png
#   inflating: image/resize_CHNCXR_0021_0.png
#   inflating: image/resize_CHNCXR_0022_0.png
#   inflating: image/resize_CHNCXR_0023_0.png
#   inflating: image/resize_CHNCXR_0024_0.png
#   inflating: image/resize_CHNCXR_0026_0.png
#   inflating: image/resize_CHNCXR_0027_0.png
#   inflating: image/resize_CHNCXR_0028_0.png
#   inflating: image/resize_CHNCXR_0029_0.png
#   inflating: image/resize_CHNCXR_0030_0.png
#   inflating: image/resize_CHNCXR_0031_0.png
#   inflating: image/resize_CHNCXR_0032_0.png
#   inflating: image/resize_CHNCXR_0033_0.png
#   inflating: image/resize_CHNCXR_0034_0.png
#   inflating: image/resize_CHNCXR_0035_0.png
#   inflating: image/resize_CHNCXR_0041_0.png
#   inflating: image/resize_CHNCXR_0042_0.png
#   inflating: image/resize_CHNCXR_0043_0.png
#   inflating: image/resize_CHNCXR_0044_0.png
#   inflating: image/resize_CHNCXR_0045_0.png
#   inflating: image/resize_CHNCXR_0046_0.png
#   inflating: image/resize_CHNCXR_0047_0.png
#   inflating: image/resize_CHNCXR_0048_0.png
#   inflating: image/resize_CHNCXR_0049_0.png
#   inflating: image/resize_CHNCXR_0050_0.png
#   inflating: image/resize_CHNCXR_0051_0.png
#   inflating: image/resize_CHNCXR_0052_0.png
#   inflating: image/resize_CHNCXR_0053_0.png
#   inflating: image/resize_CHNCXR_0054_0.png
#   inflating: image/resize_CHNCXR_0055_0.png
#   inflating: image/resize_CHNCXR_0056_0.png
#   inflating: image/resize_CHNCXR_0057_0.png
#   inflating: image/resize_CHNCXR_0058_0.png
#   inflating: image/resize_CHNCXR_0059_0.png
#   inflating: image/resize_CHNCXR_0060_0.png
#   inflating: image/resize_CHNCXR_0061_0.png
#   inflating: image/resize_CHNCXR_0062_0.png
#   inflating: image/resize_CHNCXR_0063_0.png
#   inflating: image/resize_CHNCXR_0064_0.png
#   inflating: image/resize_CHNCXR_0066_0.png
#   inflating: image/resize_CHNCXR_0067_0.png
#   inflating: image/resize_CHNCXR_0068_0.png
#   inflating: image/resize_CHNCXR_0069_0.png
#   inflating: image/resize_CHNCXR_0070_0.png
#   inflating: image/resize_CHNCXR_0071_0.png
#   inflating: image/resize_CHNCXR_0072_0.png
#   inflating: image/resize_CHNCXR_0073_0.png
#   inflating: image/resize_CHNCXR_0074_0.png
#   inflating: image/resize_CHNCXR_0075_0.png
#   inflating: image/resize_CHNCXR_0076_0.png
#   inflating: image/resize_CHNCXR_0077_0.png
#   inflating: image/resize_CHNCXR_0078_0.png
#   inflating: image/resize_CHNCXR_0079_0.png
#   inflating: image/resize_CHNCXR_0080_0.png
#   inflating: image/resize_CHNCXR_0081_0.png
#   inflating: image/resize_CHNCXR_0082_0.png
#   inflating: image/resize_CHNCXR_0083_0.png
#   inflating: image/resize_CHNCXR_0084_0.png
#   inflating: image/resize_CHNCXR_0085_0.png
#   inflating: image/resize_CHNCXR_0086_0.png
#   inflating: image/resize_CHNCXR_0087_0.png
#   inflating: image/resize_CHNCXR_0088_0.png
#   inflating: image/resize_CHNCXR_0089_0.png
#   inflating: image/resize_CHNCXR_0090_0.png
#   inflating: image/resize_CHNCXR_0091_0.png
#   inflating: image/resize_CHNCXR_0092_0.png
#   inflating: image/resize_CHNCXR_0093_0.png
#   inflating: image/resize_CHNCXR_0094_0.png
#   inflating: image/resize_CHNCXR_0095_0.png
#   inflating: image/resize_CHNCXR_0096_0.png
#   inflating: image/resize_CHNCXR_0097_0.png
#   inflating: image/resize_CHNCXR_0098_0.png
#   inflating: image/resize_CHNCXR_0099_0.png
#   inflating: image/resize_CHNCXR_0100_0.png
#   inflating: image/resize_CHNCXR_0101_0.png
#   inflating: image/resize_CHNCXR_0102_0.png
#   inflating: image/resize_CHNCXR_0103_0.png
#   inflating: image/resize_CHNCXR_0104_0.png
#   inflating: image/resize_CHNCXR_0105_0.png
#   inflating: image/resize_CHNCXR_0106_0.png
#   inflating: image/resize_CHNCXR_0107_0.png
#   inflating: image/resize_CHNCXR_0108_0.png
#   inflating: image/resize_CHNCXR_0109_0.png
#   inflating: image/resize_CHNCXR_0110_0.png
#   inflating: image/resize_CHNCXR_0111_0.png
#   inflating: image/resize_CHNCXR_0112_0.png
#   inflating: image/resize_CHNCXR_0113_0.png
#   inflating: image/resize_CHNCXR_0114_0.png
#   inflating: image/resize_CHNCXR_0115_0.png
#   inflating: image/resize_CHNCXR_0116_0.png
#   inflating: image/resize_CHNCXR_0117_0.png
#   inflating: image/resize_CHNCXR_0118_0.png
#   inflating: image/resize_CHNCXR_0119_0.png
#   inflating: image/resize_CHNCXR_0120_0.png
#   inflating: image/resize_CHNCXR_0121_0.png
#   inflating: image/resize_CHNCXR_0122_0.png
#   inflating: image/resize_CHNCXR_0123_0.png
#   inflating: image/resize_CHNCXR_0124_0.png
#   inflating: image/resize_CHNCXR_0125_0.png
#   inflating: image/resize_CHNCXR_0126_0.png
#   inflating: image/resize_CHNCXR_0127_0.png
#   inflating: image/resize_CHNCXR_0128_0.png
#   inflating: image/resize_CHNCXR_0129_0.png
#   inflating: image/resize_CHNCXR_0130_0.png
#   inflating: image/resize_CHNCXR_0131_0.png
#   inflating: image/resize_CHNCXR_0132_0.png
#   inflating: image/resize_CHNCXR_0133_0.png
#   inflating: image/resize_CHNCXR_0134_0.png
#   inflating: image/resize_CHNCXR_0135_0.png
#   inflating: image/resize_CHNCXR_0136_0.png
#   inflating: image/resize_CHNCXR_0137_0.png
#   inflating: image/resize_CHNCXR_0138_0.png
#   inflating: image/resize_CHNCXR_0139_0.png
#   inflating: image/resize_CHNCXR_0140_0.png
#   inflating: image/resize_CHNCXR_0141_0.png
#   inflating: image/resize_CHNCXR_0142_0.png
#   inflating: image/resize_CHNCXR_0143_0.png
#   inflating: image/resize_CHNCXR_0144_0.png
#   inflating: image/resize_CHNCXR_0145_0.png
#   inflating: image/resize_CHNCXR_0146_0.png
#   inflating: image/resize_CHNCXR_0147_0.png
#   inflating: image/resize_CHNCXR_0148_0.png
#   inflating: image/resize_CHNCXR_0149_0.png
#   inflating: image/resize_CHNCXR_0150_0.png
#   inflating: image/resize_CHNCXR_0151_0.png
#   inflating: image/resize_CHNCXR_0152_0.png
#   inflating: image/resize_CHNCXR_0153_0.png
#   inflating: image/resize_CHNCXR_0154_0.png
#   inflating: image/resize_CHNCXR_0155_0.png
#   inflating: image/resize_CHNCXR_0156_0.png
#   inflating: image/resize_CHNCXR_0157_0.png
#   inflating: image/resize_CHNCXR_0158_0.png
#   inflating: image/resize_CHNCXR_0159_0.png
#   inflating: image/resize_CHNCXR_0160_0.png
#   inflating: image/resize_CHNCXR_0161_0.png
#   inflating: image/resize_CHNCXR_0162_0.png
#   inflating: image/resize_CHNCXR_0163_0.png
#   inflating: image/resize_CHNCXR_0164_0.png
#   inflating: image/resize_CHNCXR_0165_0.png
#   inflating: image/resize_CHNCXR_0166_0.png
#   inflating: image/resize_CHNCXR_0167_0.png
#   inflating: image/resize_CHNCXR_0168_0.png
#   inflating: image/resize_CHNCXR_0169_0.png
#   inflating: image/resize_CHNCXR_0170_0.png
#   inflating: image/resize_CHNCXR_0171_0.png
#   inflating: image/resize_CHNCXR_0172_0.png
#   inflating: image/resize_CHNCXR_0173_0.png
#   inflating: image/resize_CHNCXR_0174_0.png
#   inflating: image/resize_CHNCXR_0175_0.png
#   inflating: image/resize_CHNCXR_0176_0.png
#   inflating: image/resize_CHNCXR_0177_0.png
#   inflating: image/resize_CHNCXR_0178_0.png
#   inflating: image/resize_CHNCXR_0179_0.png
#   inflating: image/resize_CHNCXR_0180_0.png
#   inflating: image/resize_CHNCXR_0221_0.png
#   inflating: image/resize_CHNCXR_0222_0.png
#   inflating: image/resize_CHNCXR_0223_0.png
#   inflating: image/resize_CHNCXR_0224_0.png
#   inflating: image/resize_CHNCXR_0225_0.png
#   inflating: image/resize_CHNCXR_0226_0.png
#   inflating: image/resize_CHNCXR_0227_0.png
#   inflating: image/resize_CHNCXR_0228_0.png
#   inflating: image/resize_CHNCXR_0229_0.png
#   inflating: image/resize_CHNCXR_0230_0.png
#   inflating: image/resize_CHNCXR_0231_0.png
#   inflating: image/resize_CHNCXR_0232_0.png
#   inflating: image/resize_CHNCXR_0233_0.png
#   inflating: image/resize_CHNCXR_0234_0.png
#   inflating: image/resize_CHNCXR_0235_0.png
#   inflating: image/resize_CHNCXR_0236_0.png
#   inflating: image/resize_CHNCXR_0237_0.png
#   inflating: image/resize_CHNCXR_0238_0.png
#   inflating: image/resize_CHNCXR_0239_0.png
#   inflating: image/resize_CHNCXR_0240_0.png
#   inflating: image/resize_CHNCXR_0241_0.png
#   inflating: image/resize_CHNCXR_0242_0.png
#   inflating: image/resize_CHNCXR_0243_0.png
#   inflating: image/resize_CHNCXR_0244_0.png
#   inflating: image/resize_CHNCXR_0245_0.png
#   inflating: image/resize_CHNCXR_0246_0.png
#   inflating: image/resize_CHNCXR_0247_0.png
#   inflating: image/resize_CHNCXR_0248_0.png
#   inflating: image/resize_CHNCXR_0249_0.png
#   inflating: image/resize_CHNCXR_0250_0.png
#   inflating: image/resize_CHNCXR_0251_0.png
#   inflating: image/resize_CHNCXR_0252_0.png
#   inflating: image/resize_CHNCXR_0253_0.png
#   inflating: image/resize_CHNCXR_0254_0.png
#   inflating: image/resize_CHNCXR_0255_0.png
#   inflating: image/resize_CHNCXR_0256_0.png
#   inflating: image/resize_CHNCXR_0257_0.png
#   inflating: image/resize_CHNCXR_0258_0.png
#   inflating: image/resize_CHNCXR_0259_0.png
#   inflating: image/resize_CHNCXR_0260_0.png
#   inflating: image/resize_CHNCXR_0261_0.png
#   inflating: image/resize_CHNCXR_0262_0.png
#   inflating: image/resize_CHNCXR_0263_0.png
#   inflating: image/resize_CHNCXR_0264_0.png
#   inflating: image/resize_CHNCXR_0265_0.png
#   inflating: image/resize_CHNCXR_0266_0.png
#   inflating: image/resize_CHNCXR_0267_0.png
#   inflating: image/resize_CHNCXR_0268_0.png
#   inflating: image/resize_CHNCXR_0269_0.png
#   inflating: image/resize_CHNCXR_0270_0.png
#   inflating: image/resize_CHNCXR_0271_0.png
#   inflating: image/resize_CHNCXR_0272_0.png
#   inflating: image/resize_CHNCXR_0273_0.png
#   inflating: image/resize_CHNCXR_0274_0.png
#   inflating: image/resize_CHNCXR_0275_0.png
#   inflating: image/resize_CHNCXR_0276_0.png
#   inflating: image/resize_CHNCXR_0277_0.png
#   inflating: image/resize_CHNCXR_0278_0.png
#   inflating: image/resize_CHNCXR_0279_0.png
#   inflating: image/resize_CHNCXR_0280_0.png
#   inflating: image/resize_CHNCXR_0281_0.png
#   inflating: image/resize_CHNCXR_0282_0.png
#   inflating: image/resize_CHNCXR_0283_0.png
#   inflating: image/resize_CHNCXR_0284_0.png
#   inflating: image/resize_CHNCXR_0285_0.png
#   inflating: image/resize_CHNCXR_0286_0.png
#   inflating: image/resize_CHNCXR_0287_0.png
#   inflating: image/resize_CHNCXR_0288_0.png
#   inflating: image/resize_CHNCXR_0289_0.png
#   inflating: image/resize_CHNCXR_0290_0.png
#   inflating: image/resize_CHNCXR_0291_0.png
#   inflating: image/resize_CHNCXR_0292_0.png
#   inflating: image/resize_CHNCXR_0293_0.png
#   inflating: image/resize_CHNCXR_0294_0.png
#   inflating: image/resize_CHNCXR_0295_0.png
#   inflating: image/resize_CHNCXR_0296_0.png
#   inflating: image/resize_CHNCXR_0297_0.png
#   inflating: image/resize_CHNCXR_0298_0.png
#   inflating: image/resize_CHNCXR_0299_0.png
#   inflating: image/resize_CHNCXR_0300_0.png
#   inflating: image/resize_CHNCXR_0301_0.png
#   inflating: image/resize_CHNCXR_0302_0.png
#   inflating: image/resize_CHNCXR_0303_0.png
#   inflating: image/resize_CHNCXR_0304_0.png
#   inflating: image/resize_CHNCXR_0305_0.png
#   inflating: image/resize_CHNCXR_0306_0.png
#   inflating: image/resize_CHNCXR_0307_0.png
#   inflating: image/resize_CHNCXR_0308_0.png
#   inflating: image/resize_CHNCXR_0309_0.png
#   inflating: image/resize_CHNCXR_0310_0.png
#   inflating: image/resize_CHNCXR_0311_0.png
#   inflating: image/resize_CHNCXR_0312_0.png
#   inflating: image/resize_CHNCXR_0313_0.png
#   inflating: image/resize_CHNCXR_0314_0.png
#   inflating: image/resize_CHNCXR_0315_0.png
#   inflating: image/resize_CHNCXR_0316_0.png
#   inflating: image/resize_CHNCXR_0317_0.png
#   inflating: image/resize_CHNCXR_0318_0.png
#   inflating: image/resize_CHNCXR_0319_0.png
#   inflating: image/resize_CHNCXR_0320_0.png
#   inflating: image/resize_CHNCXR_0321_0.png
#   inflating: image/resize_CHNCXR_0322_0.png
#   inflating: image/resize_CHNCXR_0323_0.png
#   inflating: image/resize_CHNCXR_0324_0.png
#   inflating: image/resize_CHNCXR_0325_0.png
#   inflating: image/resize_CHNCXR_0326_0.png
#   inflating: image/resize_CHNCXR_0327_1.png
#   inflating: image/resize_CHNCXR_0328_1.png
#   inflating: image/resize_CHNCXR_0329_1.png
#   inflating: image/resize_CHNCXR_0330_1.png
#   inflating: image/resize_CHNCXR_0331_1.png
#   inflating: image/resize_CHNCXR_0332_1.png
#   inflating: image/resize_CHNCXR_0333_1.png
#   inflating: image/resize_CHNCXR_0334_1.png
#   inflating: image/resize_CHNCXR_0335_1.png
#   inflating: image/resize_CHNCXR_0337_1.png
#   inflating: image/resize_CHNCXR_0338_1.png
#   inflating: image/resize_CHNCXR_0339_1.png
#   inflating: image/resize_CHNCXR_0340_1.png
#   inflating: image/resize_CHNCXR_0361_1.png
#   inflating: image/resize_CHNCXR_0362_1.png
#   inflating: image/resize_CHNCXR_0363_1.png
#   inflating: image/resize_CHNCXR_0364_1.png
#   inflating: image/resize_CHNCXR_0365_1.png
#   inflating: image/resize_CHNCXR_0366_1.png
#   inflating: image/resize_CHNCXR_0367_1.png
#   inflating: image/resize_CHNCXR_0368_1.png
#   inflating: image/resize_CHNCXR_0369_1.png
#   inflating: image/resize_CHNCXR_0370_1.png
#   inflating: image/resize_CHNCXR_0371_1.png
#   inflating: image/resize_CHNCXR_0372_1.png
#   inflating: image/resize_CHNCXR_0373_1.png
#   inflating: image/resize_CHNCXR_0374_1.png
#   inflating: image/resize_CHNCXR_0375_1.png
#   inflating: image/resize_CHNCXR_0376_1.png
#   inflating: image/resize_CHNCXR_0377_1.png
#   inflating: image/resize_CHNCXR_0378_1.png
#   inflating: image/resize_CHNCXR_0379_1.png
#   inflating: image/resize_CHNCXR_0380_1.png
#   inflating: image/resize_CHNCXR_0381_1.png
#   inflating: image/resize_CHNCXR_0382_1.png
#   inflating: image/resize_CHNCXR_0383_1.png
#   inflating: image/resize_CHNCXR_0384_1.png
#   inflating: image/resize_CHNCXR_0385_1.png
#   inflating: image/resize_CHNCXR_0386_1.png
#   inflating: image/resize_CHNCXR_0387_1.png
#   inflating: image/resize_CHNCXR_0388_1.png
#   inflating: image/resize_CHNCXR_0389_1.png
#   inflating: image/resize_CHNCXR_0390_1.png
#   inflating: image/resize_CHNCXR_0391_1.png
#   inflating: image/resize_CHNCXR_0392_1.png
#   inflating: image/resize_CHNCXR_0393_1.png
#   inflating: image/resize_CHNCXR_0394_1.png
#   inflating: image/resize_CHNCXR_0395_1.png
#   inflating: image/resize_CHNCXR_0396_1.png
#   inflating: image/resize_CHNCXR_0397_1.png
#   inflating: image/resize_CHNCXR_0398_1.png
#   inflating: image/resize_CHNCXR_0399_1.png
#   inflating: image/resize_CHNCXR_0400_1.png
#   inflating: image/resize_CHNCXR_0401_1.png
#   inflating: image/resize_CHNCXR_0402_1.png
#   inflating: image/resize_CHNCXR_0403_1.png
#   inflating: image/resize_CHNCXR_0404_1.png
#   inflating: image/resize_CHNCXR_0405_1.png
#   inflating: image/resize_CHNCXR_0406_1.png
#   inflating: image/resize_CHNCXR_0407_1.png
#   inflating: image/resize_CHNCXR_0408_1.png
#   inflating: image/resize_CHNCXR_0409_1.png
#   inflating: image/resize_CHNCXR_0410_1.png
#   inflating: image/resize_CHNCXR_0411_1.png
#   inflating: image/resize_CHNCXR_0412_1.png
#   inflating: image/resize_CHNCXR_0413_1.png
#   inflating: image/resize_CHNCXR_0414_1.png
#   inflating: image/resize_CHNCXR_0415_1.png
#   inflating: image/resize_CHNCXR_0416_1.png
#   inflating: image/resize_CHNCXR_0417_1.png
#   inflating: image/resize_CHNCXR_0418_1.png
#   inflating: image/resize_CHNCXR_0419_1.png
#   inflating: image/resize_CHNCXR_0420_1.png
#   inflating: image/resize_CHNCXR_0421_1.png
#   inflating: image/resize_CHNCXR_0422_1.png
#   inflating: image/resize_CHNCXR_0423_1.png
#   inflating: image/resize_CHNCXR_0424_1.png
#   inflating: image/resize_CHNCXR_0425_1.png
#   inflating: image/resize_CHNCXR_0426_1.png
#   inflating: image/resize_CHNCXR_0427_1.png
#   inflating: image/resize_CHNCXR_0428_1.png
#   inflating: image/resize_CHNCXR_0429_1.png
#   inflating: image/resize_CHNCXR_0430_1.png
#   inflating: image/resize_CHNCXR_0431_1.png
#   inflating: image/resize_CHNCXR_0432_1.png
#   inflating: image/resize_CHNCXR_0433_1.png
#   inflating: image/resize_CHNCXR_0434_1.png
#   inflating: image/resize_CHNCXR_0435_1.png
#   inflating: image/resize_CHNCXR_0436_1.png
#   inflating: image/resize_CHNCXR_0437_1.png
#   inflating: image/resize_CHNCXR_0438_1.png
#   inflating: image/resize_CHNCXR_0439_1.png
#   inflating: image/resize_CHNCXR_0440_1.png
#   inflating: image/resize_CHNCXR_0441_1.png
#   inflating: image/resize_CHNCXR_0442_1.png
#   inflating: image/resize_CHNCXR_0443_1.png
#   inflating: image/resize_CHNCXR_0444_1.png
#   inflating: image/resize_CHNCXR_0445_1.png
#   inflating: image/resize_CHNCXR_0446_1.png
#   inflating: image/resize_CHNCXR_0447_1.png
#   inflating: image/resize_CHNCXR_0448_1.png
#   inflating: image/resize_CHNCXR_0449_1.png
#   inflating: image/resize_CHNCXR_0450_1.png
#   inflating: image/resize_CHNCXR_0451_1.png
#   inflating: image/resize_CHNCXR_0452_1.png
#   inflating: image/resize_CHNCXR_0453_1.png
#   inflating: image/resize_CHNCXR_0454_1.png
#   inflating: image/resize_CHNCXR_0455_1.png
#   inflating: image/resize_CHNCXR_0456_1.png
#   inflating: image/resize_CHNCXR_0457_1.png
#   inflating: image/resize_CHNCXR_0458_1.png
#   inflating: image/resize_CHNCXR_0459_1.png
#   inflating: image/resize_CHNCXR_0460_1.png
#   inflating: image/resize_CHNCXR_0461_1.png
#   inflating: image/resize_CHNCXR_0462_1.png
#   inflating: image/resize_CHNCXR_0463_1.png
#   inflating: image/resize_CHNCXR_0464_1.png
#   inflating: image/resize_CHNCXR_0465_1.png
#   inflating: image/resize_CHNCXR_0466_1.png
#   inflating: image/resize_CHNCXR_0467_1.png
#   inflating: image/resize_CHNCXR_0468_1.png
#   inflating: image/resize_CHNCXR_0469_1.png
#   inflating: image/resize_CHNCXR_0470_1.png
#   inflating: image/resize_CHNCXR_0471_1.png
#   inflating: image/resize_CHNCXR_0472_1.png
#   inflating: image/resize_CHNCXR_0473_1.png
#   inflating: image/resize_CHNCXR_0474_1.png
#   inflating: image/resize_CHNCXR_0475_1.png
#   inflating: image/resize_CHNCXR_0476_1.png
#   inflating: image/resize_CHNCXR_0477_1.png
#   inflating: image/resize_CHNCXR_0478_1.png
#   inflating: image/resize_CHNCXR_0479_1.png
#   inflating: image/resize_CHNCXR_0480_1.png
#   inflating: image/resize_CHNCXR_0501_1.png
#   inflating: image/resize_CHNCXR_0503_1.png
#   inflating: image/resize_CHNCXR_0504_1.png
#   inflating: image/resize_CHNCXR_0506_1.png
#   inflating: image/resize_CHNCXR_0507_1.png
#   inflating: image/resize_CHNCXR_0508_1.png
#   inflating: image/resize_CHNCXR_0509_1.png
#   inflating: image/resize_CHNCXR_0510_1.png
#   inflating: image/resize_CHNCXR_0511_1.png
#   inflating: image/resize_CHNCXR_0512_1.png
#   inflating: image/resize_CHNCXR_0513_1.png
#   inflating: image/resize_CHNCXR_0514_1.png
#   inflating: image/resize_CHNCXR_0515_1.png
#   inflating: image/resize_CHNCXR_0516_1.png
#   inflating: image/resize_CHNCXR_0517_1.png
#   inflating: image/resize_CHNCXR_0518_1.png
#   inflating: image/resize_CHNCXR_0519_1.png
#   inflating: image/resize_CHNCXR_0520_1.png
#   inflating: image/resize_CHNCXR_0521_1.png
#   inflating: image/resize_CHNCXR_0522_1.png
#   inflating: image/resize_CHNCXR_0523_1.png
#   inflating: image/resize_CHNCXR_0524_1.png
#   inflating: image/resize_CHNCXR_0525_1.png
#   inflating: image/resize_CHNCXR_0526_1.png
#   inflating: image/resize_CHNCXR_0527_1.png
#   inflating: image/resize_CHNCXR_0528_1.png
#   inflating: image/resize_CHNCXR_0529_1.png
#   inflating: image/resize_CHNCXR_0530_1.png
#   inflating: image/resize_CHNCXR_0531_1.png
#   inflating: image/resize_CHNCXR_0532_1.png
#   inflating: image/resize_CHNCXR_0533_1.png
#   inflating: image/resize_CHNCXR_0534_1.png
#   inflating: image/resize_CHNCXR_0535_1.png
#   inflating: image/resize_CHNCXR_0536_1.png
#   inflating: image/resize_CHNCXR_0537_1.png
#   inflating: image/resize_CHNCXR_0538_1.png
#   inflating: image/resize_CHNCXR_0539_1.png
#   inflating: image/resize_CHNCXR_0540_1.png
#   inflating: image/resize_CHNCXR_0541_1.png
#   inflating: image/resize_CHNCXR_0542_1.png
#   inflating: image/resize_CHNCXR_0543_1.png
#   inflating: image/resize_CHNCXR_0544_1.png
#   inflating: image/resize_CHNCXR_0545_1.png
#   inflating: image/resize_CHNCXR_0546_1.png
#   inflating: image/resize_CHNCXR_0547_1.png
#   inflating: image/resize_CHNCXR_0548_1.png
#   inflating: image/resize_CHNCXR_0549_1.png
#   inflating: image/resize_CHNCXR_0550_1.png
#   inflating: image/resize_CHNCXR_0551_1.png
#   inflating: image/resize_CHNCXR_0552_1.png
#   inflating: image/resize_CHNCXR_0553_1.png
#   inflating: image/resize_CHNCXR_0554_1.png
#   inflating: image/resize_CHNCXR_0555_1.png
#   inflating: image/resize_CHNCXR_0556_1.png
#   inflating: image/resize_CHNCXR_0557_1.png
#   inflating: image/resize_CHNCXR_0558_1.png
#   inflating: image/resize_CHNCXR_0559_1.png
#   inflating: image/resize_CHNCXR_0566_1.png
#   inflating: image/resize_CHNCXR_0567_1.png
#   inflating: image/resize_CHNCXR_0568_1.png
#   inflating: image/resize_CHNCXR_0569_1.png
#   inflating: image/resize_CHNCXR_0570_1.png
#   inflating: image/resize_CHNCXR_0571_1.png
#   inflating: image/resize_CHNCXR_0572_1.png
#   inflating: image/resize_CHNCXR_0573_1.png
#   inflating: image/resize_CHNCXR_0574_1.png
#   inflating: image/resize_CHNCXR_0575_1.png
#   inflating: image/resize_CHNCXR_0576_1.png
#   inflating: image/resize_CHNCXR_0577_1.png
#   inflating: image/resize_CHNCXR_0578_1.png
#   inflating: image/resize_CHNCXR_0579_1.png
#   inflating: image/resize_CHNCXR_0580_1.png
#   inflating: image/resize_CHNCXR_0581_1.png
#   inflating: image/resize_CHNCXR_0582_1.png
#   inflating: image/resize_CHNCXR_0583_1.png
#   inflating: image/resize_CHNCXR_0584_1.png
#   inflating: image/resize_CHNCXR_0585_1.png
#   inflating: image/resize_CHNCXR_0586_1.png
#   inflating: image/resize_CHNCXR_0587_1.png
#   inflating: image/resize_CHNCXR_0588_1.png
#   inflating: image/resize_CHNCXR_0589_1.png
#   inflating: image/resize_CHNCXR_0590_1.png
#   inflating: image/resize_CHNCXR_0591_1.png
#   inflating: image/resize_CHNCXR_0592_1.png
#   inflating: image/resize_CHNCXR_0593_1.png
#   inflating: image/resize_CHNCXR_0594_1.png
#   inflating: image/resize_CHNCXR_0595_1.png
#   inflating: image/resize_CHNCXR_0596_1.png
#   inflating: image/resize_CHNCXR_0597_1.png
#   inflating: image/resize_CHNCXR_0598_1.png
#   inflating: image/resize_CHNCXR_0599_1.png
#   inflating: image/resize_CHNCXR_0600_1.png
#   inflating: image/resize_CHNCXR_0601_1.png
#   inflating: image/resize_CHNCXR_0602_1.png
#   inflating: image/resize_CHNCXR_0603_1.png
#   inflating: image/resize_CHNCXR_0604_1.png
#   inflating: image/resize_CHNCXR_0605_1.png
#   inflating: image/resize_CHNCXR_0606_1.png
#   inflating: image/resize_CHNCXR_0607_1.png
#   inflating: image/resize_CHNCXR_0608_1.png
#   inflating: image/resize_CHNCXR_0609_1.png
#   inflating: image/resize_CHNCXR_0610_1.png
#   inflating: image/resize_CHNCXR_0611_1.png
#   inflating: image/resize_CHNCXR_0612_1.png
#   inflating: image/resize_CHNCXR_0613_1.png
#   inflating: image/resize_CHNCXR_0614_1.png
#   inflating: image/resize_CHNCXR_0615_1.png
#   inflating: image/resize_CHNCXR_0616_1.png
#   inflating: image/resize_CHNCXR_0617_1.png
#   inflating: image/resize_CHNCXR_0618_1.png
#   inflating: image/resize_CHNCXR_0619_1.png
#   inflating: image/resize_CHNCXR_0620_1.png
#   inflating: image/resize_CHNCXR_0621_1.png
#   inflating: image/resize_CHNCXR_0622_1.png
#   inflating: image/resize_CHNCXR_0623_1.png
#   inflating: image/resize_CHNCXR_0624_1.png
#   inflating: image/resize_CHNCXR_0625_1.png
#   inflating: image/resize_CHNCXR_0626_1.png
#   inflating: image/resize_CHNCXR_0627_1.png
#   inflating: image/resize_CHNCXR_0628_1.png
#   inflating: image/resize_CHNCXR_0629_1.png
#   inflating: image/resize_CHNCXR_0630_1.png
#   inflating: image/resize_CHNCXR_0631_1.png
#   inflating: image/resize_CHNCXR_0632_1.png
#   inflating: image/resize_CHNCXR_0633_1.png
#   inflating: image/resize_CHNCXR_0634_1.png
#   inflating: image/resize_CHNCXR_0635_1.png
#   inflating: image/resize_CHNCXR_0636_1.png
#   inflating: image/resize_CHNCXR_0637_1.png
#   inflating: image/resize_CHNCXR_0638_1.png
#   inflating: image/resize_CHNCXR_0639_1.png
#   inflating: image/resize_CHNCXR_0640_1.png
#   inflating: image/resize_CHNCXR_0641_1.png
#   inflating: image/resize_CHNCXR_0642_1.png
#   inflating: image/resize_CHNCXR_0643_1.png
#   inflating: image/resize_CHNCXR_0644_1.png
#   inflating: image/resize_CHNCXR_0645_1.png
#   inflating: image/resize_CHNCXR_0646_1.png
#   inflating: image/resize_CHNCXR_0647_1.png
#   inflating: image/resize_CHNCXR_0648_1.png
#   inflating: image/resize_CHNCXR_0649_1.png
#   inflating: image/resize_CHNCXR_0650_1.png
#   inflating: image/resize_CHNCXR_0651_1.png
#   inflating: image/resize_CHNCXR_0652_1.png
#   inflating: image/resize_CHNCXR_0653_1.png
#   inflating: image/resize_CHNCXR_0654_1.png
#   inflating: image/resize_CHNCXR_0655_1.png
#   inflating: image/resize_CHNCXR_0656_1.png
#   inflating: image/resize_CHNCXR_0657_1.png
#   inflating: image/resize_CHNCXR_0658_1.png
#   inflating: image/resize_CHNCXR_0659_1.png
#   inflating: image/resize_CHNCXR_0660_1.png
#   inflating: image/resize_CHNCXR_0661_1.png
#   inflating: image/resize_CHNCXR_0662_1.png
#   inflating: label/resize_CHNCXR_0001_0.png
#   inflating: label/resize_CHNCXR_0002_0.png
#   inflating: label/resize_CHNCXR_0003_0.png
#   inflating: label/resize_CHNCXR_0004_0.png
#   inflating: label/resize_CHNCXR_0005_0.png
#   inflating: label/resize_CHNCXR_0006_0.png
#   inflating: label/resize_CHNCXR_0007_0.png
#   inflating: label/resize_CHNCXR_0008_0.png
#   inflating: label/resize_CHNCXR_0009_0.png
#   inflating: label/resize_CHNCXR_0010_0.png
#   inflating: label/resize_CHNCXR_0011_0.png
#   inflating: label/resize_CHNCXR_0012_0.png
#   inflating: label/resize_CHNCXR_0013_0.png
#   inflating: label/resize_CHNCXR_0014_0.png
#   inflating: label/resize_CHNCXR_0015_0.png
#   inflating: label/resize_CHNCXR_0016_0.png
#   inflating: label/resize_CHNCXR_0017_0.png
#   inflating: label/resize_CHNCXR_0018_0.png
#   inflating: label/resize_CHNCXR_0019_0.png
#   inflating: label/resize_CHNCXR_0020_0.png
#   inflating: label/resize_CHNCXR_0021_0.png
#   inflating: label/resize_CHNCXR_0022_0.png
#   inflating: label/resize_CHNCXR_0023_0.png
#   inflating: label/resize_CHNCXR_0024_0.png
#   inflating: label/resize_CHNCXR_0026_0.png
#   inflating: label/resize_CHNCXR_0027_0.png
#   inflating: label/resize_CHNCXR_0028_0.png
#   inflating: label/resize_CHNCXR_0029_0.png
#   inflating: label/resize_CHNCXR_0030_0.png
#   inflating: label/resize_CHNCXR_0031_0.png
#   inflating: label/resize_CHNCXR_0032_0.png
#   inflating: label/resize_CHNCXR_0033_0.png
#   inflating: label/resize_CHNCXR_0034_0.png
#   inflating: label/resize_CHNCXR_0035_0.png
#   inflating: label/resize_CHNCXR_0041_0.png
#   inflating: label/resize_CHNCXR_0042_0.png
#   inflating: label/resize_CHNCXR_0043_0.png
#   inflating: label/resize_CHNCXR_0044_0.png
#   inflating: label/resize_CHNCXR_0045_0.png
#   inflating: label/resize_CHNCXR_0046_0.png
#   inflating: label/resize_CHNCXR_0047_0.png
#   inflating: label/resize_CHNCXR_0048_0.png
#   inflating: label/resize_CHNCXR_0049_0.png
#   inflating: label/resize_CHNCXR_0050_0.png
#   inflating: label/resize_CHNCXR_0051_0.png
#   inflating: label/resize_CHNCXR_0052_0.png
#   inflating: label/resize_CHNCXR_0053_0.png
#   inflating: label/resize_CHNCXR_0054_0.png
#   inflating: label/resize_CHNCXR_0055_0.png
#   inflating: label/resize_CHNCXR_0056_0.png
#   inflating: label/resize_CHNCXR_0057_0.png
#   inflating: label/resize_CHNCXR_0058_0.png
#   inflating: label/resize_CHNCXR_0059_0.png
#   inflating: label/resize_CHNCXR_0060_0.png
#   inflating: label/resize_CHNCXR_0061_0.png
#   inflating: label/resize_CHNCXR_0062_0.png
#   inflating: label/resize_CHNCXR_0063_0.png
#   inflating: label/resize_CHNCXR_0064_0.png
#   inflating: label/resize_CHNCXR_0066_0.png
#   inflating: label/resize_CHNCXR_0067_0.png
#   inflating: label/resize_CHNCXR_0068_0.png
#   inflating: label/resize_CHNCXR_0069_0.png
#   inflating: label/resize_CHNCXR_0070_0.png
#   inflating: label/resize_CHNCXR_0071_0.png
#   inflating: label/resize_CHNCXR_0072_0.png
#   inflating: label/resize_CHNCXR_0073_0.png
#   inflating: label/resize_CHNCXR_0074_0.png
#   inflating: label/resize_CHNCXR_0075_0.png
#   inflating: label/resize_CHNCXR_0076_0.png
#   inflating: label/resize_CHNCXR_0077_0.png
#   inflating: label/resize_CHNCXR_0078_0.png
#   inflating: label/resize_CHNCXR_0079_0.png
#   inflating: label/resize_CHNCXR_0080_0.png
#   inflating: label/resize_CHNCXR_0081_0.png
#   inflating: label/resize_CHNCXR_0082_0.png
#   inflating: label/resize_CHNCXR_0083_0.png
#   inflating: label/resize_CHNCXR_0084_0.png
#   inflating: label/resize_CHNCXR_0085_0.png
#   inflating: label/resize_CHNCXR_0086_0.png
#   inflating: label/resize_CHNCXR_0087_0.png
#   inflating: label/resize_CHNCXR_0088_0.png
#   inflating: label/resize_CHNCXR_0089_0.png
#   inflating: label/resize_CHNCXR_0090_0.png
#   inflating: label/resize_CHNCXR_0091_0.png
#   inflating: label/resize_CHNCXR_0092_0.png
#   inflating: label/resize_CHNCXR_0093_0.png
#   inflating: label/resize_CHNCXR_0094_0.png
#   inflating: label/resize_CHNCXR_0095_0.png
#   inflating: label/resize_CHNCXR_0096_0.png
#   inflating: label/resize_CHNCXR_0097_0.png
#   inflating: label/resize_CHNCXR_0098_0.png
#   inflating: label/resize_CHNCXR_0099_0.png
#   inflating: label/resize_CHNCXR_0100_0.png
#   inflating: label/resize_CHNCXR_0101_0.png
#   inflating: label/resize_CHNCXR_0102_0.png
#   inflating: label/resize_CHNCXR_0103_0.png
#   inflating: label/resize_CHNCXR_0104_0.png
#   inflating: label/resize_CHNCXR_0105_0.png
#   inflating: label/resize_CHNCXR_0106_0.png
#   inflating: label/resize_CHNCXR_0107_0.png
#   inflating: label/resize_CHNCXR_0108_0.png
#   inflating: label/resize_CHNCXR_0109_0.png
#   inflating: label/resize_CHNCXR_0110_0.png
#   inflating: label/resize_CHNCXR_0111_0.png
#   inflating: label/resize_CHNCXR_0112_0.png
#   inflating: label/resize_CHNCXR_0113_0.png
#   inflating: label/resize_CHNCXR_0114_0.png
#   inflating: label/resize_CHNCXR_0115_0.png
#   inflating: label/resize_CHNCXR_0116_0.png
#   inflating: label/resize_CHNCXR_0117_0.png
#   inflating: label/resize_CHNCXR_0118_0.png
#   inflating: label/resize_CHNCXR_0119_0.png
#   inflating: label/resize_CHNCXR_0120_0.png
#   inflating: label/resize_CHNCXR_0121_0.png
#   inflating: label/resize_CHNCXR_0122_0.png
#   inflating: label/resize_CHNCXR_0123_0.png
#   inflating: label/resize_CHNCXR_0124_0.png
#   inflating: label/resize_CHNCXR_0125_0.png
#   inflating: label/resize_CHNCXR_0126_0.png
#   inflating: label/resize_CHNCXR_0127_0.png
#   inflating: label/resize_CHNCXR_0128_0.png
#   inflating: label/resize_CHNCXR_0129_0.png
#   inflating: label/resize_CHNCXR_0130_0.png
#   inflating: label/resize_CHNCXR_0131_0.png
#   inflating: label/resize_CHNCXR_0132_0.png
#   inflating: label/resize_CHNCXR_0133_0.png
#   inflating: label/resize_CHNCXR_0134_0.png
#   inflating: label/resize_CHNCXR_0135_0.png
#   inflating: label/resize_CHNCXR_0136_0.png
#   inflating: label/resize_CHNCXR_0137_0.png
#   inflating: label/resize_CHNCXR_0138_0.png
#   inflating: label/resize_CHNCXR_0139_0.png
#   inflating: label/resize_CHNCXR_0140_0.png
#   inflating: label/resize_CHNCXR_0141_0.png
#   inflating: label/resize_CHNCXR_0142_0.png
#   inflating: label/resize_CHNCXR_0143_0.png
#   inflating: label/resize_CHNCXR_0144_0.png
#   inflating: label/resize_CHNCXR_0145_0.png
#   inflating: label/resize_CHNCXR_0146_0.png
#   inflating: label/resize_CHNCXR_0147_0.png
#   inflating: label/resize_CHNCXR_0148_0.png
#   inflating: label/resize_CHNCXR_0149_0.png
#   inflating: label/resize_CHNCXR_0150_0.png
#   inflating: label/resize_CHNCXR_0151_0.png
#   inflating: label/resize_CHNCXR_0152_0.png
#   inflating: label/resize_CHNCXR_0153_0.png
#   inflating: label/resize_CHNCXR_0154_0.png
#   inflating: label/resize_CHNCXR_0155_0.png
#   inflating: label/resize_CHNCXR_0156_0.png
#   inflating: label/resize_CHNCXR_0157_0.png
#   inflating: label/resize_CHNCXR_0158_0.png
#   inflating: label/resize_CHNCXR_0159_0.png
#   inflating: label/resize_CHNCXR_0160_0.png
#   inflating: label/resize_CHNCXR_0161_0.png
#   inflating: label/resize_CHNCXR_0162_0.png
#   inflating: label/resize_CHNCXR_0163_0.png
#   inflating: label/resize_CHNCXR_0164_0.png
#   inflating: label/resize_CHNCXR_0165_0.png
#   inflating: label/resize_CHNCXR_0166_0.png
#   inflating: label/resize_CHNCXR_0167_0.png
#   inflating: label/resize_CHNCXR_0168_0.png
#   inflating: label/resize_CHNCXR_0169_0.png
#   inflating: label/resize_CHNCXR_0170_0.png
#   inflating: label/resize_CHNCXR_0171_0.png
#   inflating: label/resize_CHNCXR_0172_0.png
#   inflating: label/resize_CHNCXR_0173_0.png
#   inflating: label/resize_CHNCXR_0174_0.png
#   inflating: label/resize_CHNCXR_0175_0.png
#   inflating: label/resize_CHNCXR_0176_0.png
#   inflating: label/resize_CHNCXR_0177_0.png
#   inflating: label/resize_CHNCXR_0178_0.png
#   inflating: label/resize_CHNCXR_0179_0.png
#   inflating: label/resize_CHNCXR_0180_0.png
#   inflating: label/resize_CHNCXR_0221_0.png
#   inflating: label/resize_CHNCXR_0222_0.png
#   inflating: label/resize_CHNCXR_0223_0.png
#   inflating: label/resize_CHNCXR_0224_0.png
#   inflating: label/resize_CHNCXR_0225_0.png
#   inflating: label/resize_CHNCXR_0226_0.png
#   inflating: label/resize_CHNCXR_0227_0.png
#   inflating: label/resize_CHNCXR_0228_0.png
#   inflating: label/resize_CHNCXR_0229_0.png
#   inflating: label/resize_CHNCXR_0230_0.png
#   inflating: label/resize_CHNCXR_0231_0.png
#   inflating: label/resize_CHNCXR_0232_0.png
#   inflating: label/resize_CHNCXR_0233_0.png
#   inflating: label/resize_CHNCXR_0234_0.png
#   inflating: label/resize_CHNCXR_0235_0.png
#   inflating: label/resize_CHNCXR_0236_0.png
#   inflating: label/resize_CHNCXR_0237_0.png
#   inflating: label/resize_CHNCXR_0238_0.png
#   inflating: label/resize_CHNCXR_0239_0.png
#   inflating: label/resize_CHNCXR_0240_0.png
#   inflating: label/resize_CHNCXR_0241_0.png
#   inflating: label/resize_CHNCXR_0242_0.png
#   inflating: label/resize_CHNCXR_0243_0.png
#   inflating: label/resize_CHNCXR_0244_0.png
#   inflating: label/resize_CHNCXR_0245_0.png
#   inflating: label/resize_CHNCXR_0246_0.png
#   inflating: label/resize_CHNCXR_0247_0.png
#   inflating: label/resize_CHNCXR_0248_0.png
#   inflating: label/resize_CHNCXR_0249_0.png
#   inflating: label/resize_CHNCXR_0250_0.png
#   inflating: label/resize_CHNCXR_0251_0.png
#   inflating: label/resize_CHNCXR_0252_0.png
#   inflating: label/resize_CHNCXR_0253_0.png
#   inflating: label/resize_CHNCXR_0254_0.png
#   inflating: label/resize_CHNCXR_0255_0.png
#   inflating: label/resize_CHNCXR_0256_0.png
#   inflating: label/resize_CHNCXR_0257_0.png
#   inflating: label/resize_CHNCXR_0258_0.png
#   inflating: label/resize_CHNCXR_0259_0.png
#   inflating: label/resize_CHNCXR_0260_0.png
#   inflating: label/resize_CHNCXR_0261_0.png
#   inflating: label/resize_CHNCXR_0262_0.png
#   inflating: label/resize_CHNCXR_0263_0.png
#   inflating: label/resize_CHNCXR_0264_0.png
#   inflating: label/resize_CHNCXR_0265_0.png
#   inflating: label/resize_CHNCXR_0266_0.png
#   inflating: label/resize_CHNCXR_0267_0.png
#   inflating: label/resize_CHNCXR_0268_0.png
#   inflating: label/resize_CHNCXR_0269_0.png
#   inflating: label/resize_CHNCXR_0270_0.png
#   inflating: label/resize_CHNCXR_0271_0.png
#   inflating: label/resize_CHNCXR_0272_0.png
#   inflating: label/resize_CHNCXR_0273_0.png
#   inflating: label/resize_CHNCXR_0274_0.png
#   inflating: label/resize_CHNCXR_0275_0.png
#   inflating: label/resize_CHNCXR_0276_0.png
#   inflating: label/resize_CHNCXR_0277_0.png
#   inflating: label/resize_CHNCXR_0278_0.png
#   inflating: label/resize_CHNCXR_0279_0.png
#   inflating: label/resize_CHNCXR_0280_0.png
#   inflating: label/resize_CHNCXR_0281_0.png
#   inflating: label/resize_CHNCXR_0282_0.png
#   inflating: label/resize_CHNCXR_0283_0.png
#   inflating: label/resize_CHNCXR_0284_0.png
#   inflating: label/resize_CHNCXR_0285_0.png
#   inflating: label/resize_CHNCXR_0286_0.png
#   inflating: label/resize_CHNCXR_0287_0.png
#   inflating: label/resize_CHNCXR_0288_0.png
#   inflating: label/resize_CHNCXR_0289_0.png
#   inflating: label/resize_CHNCXR_0290_0.png
#   inflating: label/resize_CHNCXR_0291_0.png
#   inflating: label/resize_CHNCXR_0292_0.png
#   inflating: label/resize_CHNCXR_0293_0.png
#   inflating: label/resize_CHNCXR_0294_0.png
#   inflating: label/resize_CHNCXR_0295_0.png
#   inflating: label/resize_CHNCXR_0296_0.png
#   inflating: label/resize_CHNCXR_0297_0.png
#   inflating: label/resize_CHNCXR_0298_0.png
#   inflating: label/resize_CHNCXR_0299_0.png
#   inflating: label/resize_CHNCXR_0300_0.png
#   inflating: label/resize_CHNCXR_0301_0.png
#   inflating: label/resize_CHNCXR_0302_0.png
#   inflating: label/resize_CHNCXR_0303_0.png
#   inflating: label/resize_CHNCXR_0304_0.png
#   inflating: label/resize_CHNCXR_0305_0.png
#   inflating: label/resize_CHNCXR_0306_0.png
#   inflating: label/resize_CHNCXR_0307_0.png
#   inflating: label/resize_CHNCXR_0308_0.png
#   inflating: label/resize_CHNCXR_0309_0.png
#   inflating: label/resize_CHNCXR_0310_0.png
#   inflating: label/resize_CHNCXR_0311_0.png
#   inflating: label/resize_CHNCXR_0312_0.png
#   inflating: label/resize_CHNCXR_0313_0.png
#   inflating: label/resize_CHNCXR_0314_0.png
#   inflating: label/resize_CHNCXR_0315_0.png
#   inflating: label/resize_CHNCXR_0316_0.png
#   inflating: label/resize_CHNCXR_0317_0.png
#   inflating: label/resize_CHNCXR_0318_0.png
#   inflating: label/resize_CHNCXR_0319_0.png
#   inflating: label/resize_CHNCXR_0320_0.png
#   inflating: label/resize_CHNCXR_0321_0.png
#   inflating: label/resize_CHNCXR_0322_0.png
#   inflating: label/resize_CHNCXR_0323_0.png
#   inflating: label/resize_CHNCXR_0324_0.png
#   inflating: label/resize_CHNCXR_0325_0.png
#   inflating: label/resize_CHNCXR_0326_0.png
#   inflating: label/resize_CHNCXR_0327_1.png
#   inflating: label/resize_CHNCXR_0328_1.png
#   inflating: label/resize_CHNCXR_0329_1.png
#   inflating: label/resize_CHNCXR_0330_1.png
#   inflating: label/resize_CHNCXR_0331_1.png
#   inflating: label/resize_CHNCXR_0332_1.png
#   inflating: label/resize_CHNCXR_0333_1.png
#   inflating: label/resize_CHNCXR_0334_1.png
#   inflating: label/resize_CHNCXR_0335_1.png
#   inflating: label/resize_CHNCXR_0337_1.png
#   inflating: label/resize_CHNCXR_0338_1.png
#   inflating: label/resize_CHNCXR_0339_1.png
#   inflating: label/resize_CHNCXR_0340_1.png
#   inflating: label/resize_CHNCXR_0361_1.png
#   inflating: label/resize_CHNCXR_0362_1.png
#   inflating: label/resize_CHNCXR_0363_1.png
#   inflating: label/resize_CHNCXR_0364_1.png
#   inflating: label/resize_CHNCXR_0365_1.png
#   inflating: label/resize_CHNCXR_0366_1.png
#   inflating: label/resize_CHNCXR_0367_1.png
#   inflating: label/resize_CHNCXR_0368_1.png
#   inflating: label/resize_CHNCXR_0369_1.png
#   inflating: label/resize_CHNCXR_0370_1.png
#   inflating: label/resize_CHNCXR_0371_1.png
#   inflating: label/resize_CHNCXR_0372_1.png
#   inflating: label/resize_CHNCXR_0373_1.png
#   inflating: label/resize_CHNCXR_0374_1.png
#   inflating: label/resize_CHNCXR_0375_1.png
#   inflating: label/resize_CHNCXR_0376_1.png
#   inflating: label/resize_CHNCXR_0377_1.png
#   inflating: label/resize_CHNCXR_0378_1.png
#   inflating: label/resize_CHNCXR_0379_1.png
#   inflating: label/resize_CHNCXR_0380_1.png
#   inflating: label/resize_CHNCXR_0381_1.png
#   inflating: label/resize_CHNCXR_0382_1.png
#   inflating: label/resize_CHNCXR_0383_1.png
#   inflating: label/resize_CHNCXR_0384_1.png
#   inflating: label/resize_CHNCXR_0385_1.png
#   inflating: label/resize_CHNCXR_0386_1.png
#   inflating: label/resize_CHNCXR_0387_1.png
#   inflating: label/resize_CHNCXR_0388_1.png
#   inflating: label/resize_CHNCXR_0389_1.png
#   inflating: label/resize_CHNCXR_0390_1.png
#   inflating: label/resize_CHNCXR_0391_1.png
#   inflating: label/resize_CHNCXR_0392_1.png
#   inflating: label/resize_CHNCXR_0393_1.png
#   inflating: label/resize_CHNCXR_0394_1.png
#   inflating: label/resize_CHNCXR_0395_1.png
#   inflating: label/resize_CHNCXR_0396_1.png
#   inflating: label/resize_CHNCXR_0397_1.png
#   inflating: label/resize_CHNCXR_0398_1.png
#   inflating: label/resize_CHNCXR_0399_1.png
#   inflating: label/resize_CHNCXR_0400_1.png
#   inflating: label/resize_CHNCXR_0401_1.png
#   inflating: label/resize_CHNCXR_0402_1.png
#   inflating: label/resize_CHNCXR_0403_1.png
#   inflating: label/resize_CHNCXR_0404_1.png
#   inflating: label/resize_CHNCXR_0405_1.png
#   inflating: label/resize_CHNCXR_0406_1.png
#   inflating: label/resize_CHNCXR_0407_1.png
#   inflating: label/resize_CHNCXR_0408_1.png
#   inflating: label/resize_CHNCXR_0409_1.png
#   inflating: label/resize_CHNCXR_0410_1.png
#   inflating: label/resize_CHNCXR_0411_1.png
#   inflating: label/resize_CHNCXR_0412_1.png
#   inflating: label/resize_CHNCXR_0413_1.png
#   inflating: label/resize_CHNCXR_0414_1.png
#   inflating: label/resize_CHNCXR_0415_1.png
#   inflating: label/resize_CHNCXR_0416_1.png
#   inflating: label/resize_CHNCXR_0417_1.png
#   inflating: label/resize_CHNCXR_0418_1.png
#   inflating: label/resize_CHNCXR_0419_1.png
#   inflating: label/resize_CHNCXR_0420_1.png
#   inflating: label/resize_CHNCXR_0421_1.png
#   inflating: label/resize_CHNCXR_0422_1.png
#   inflating: label/resize_CHNCXR_0423_1.png
#   inflating: label/resize_CHNCXR_0424_1.png
#   inflating: label/resize_CHNCXR_0425_1.png
#   inflating: label/resize_CHNCXR_0426_1.png
#   inflating: label/resize_CHNCXR_0427_1.png
#   inflating: label/resize_CHNCXR_0428_1.png
#   inflating: label/resize_CHNCXR_0429_1.png
#   inflating: label/resize_CHNCXR_0430_1.png
#   inflating: label/resize_CHNCXR_0431_1.png
#   inflating: label/resize_CHNCXR_0432_1.png
#   inflating: label/resize_CHNCXR_0433_1.png
#   inflating: label/resize_CHNCXR_0434_1.png
#   inflating: label/resize_CHNCXR_0435_1.png
#   inflating: label/resize_CHNCXR_0436_1.png
#   inflating: label/resize_CHNCXR_0437_1.png
#   inflating: label/resize_CHNCXR_0438_1.png
#   inflating: label/resize_CHNCXR_0439_1.png
#   inflating: label/resize_CHNCXR_0440_1.png
#   inflating: label/resize_CHNCXR_0441_1.png
#   inflating: label/resize_CHNCXR_0442_1.png
#   inflating: label/resize_CHNCXR_0443_1.png
#   inflating: label/resize_CHNCXR_0444_1.png
#   inflating: label/resize_CHNCXR_0445_1.png
#   inflating: label/resize_CHNCXR_0446_1.png
#   inflating: label/resize_CHNCXR_0447_1.png
#   inflating: label/resize_CHNCXR_0448_1.png
#   inflating: label/resize_CHNCXR_0449_1.png
#   inflating: label/resize_CHNCXR_0450_1.png
#   inflating: label/resize_CHNCXR_0451_1.png
#   inflating: label/resize_CHNCXR_0452_1.png
#   inflating: label/resize_CHNCXR_0453_1.png
#   inflating: label/resize_CHNCXR_0454_1.png
#   inflating: label/resize_CHNCXR_0455_1.png
#   inflating: label/resize_CHNCXR_0456_1.png
#   inflating: label/resize_CHNCXR_0457_1.png
#   inflating: label/resize_CHNCXR_0458_1.png
#   inflating: label/resize_CHNCXR_0459_1.png
#   inflating: label/resize_CHNCXR_0460_1.png
#   inflating: label/resize_CHNCXR_0461_1.png
#   inflating: label/resize_CHNCXR_0462_1.png
#   inflating: label/resize_CHNCXR_0463_1.png
#   inflating: label/resize_CHNCXR_0464_1.png
#   inflating: label/resize_CHNCXR_0465_1.png
#   inflating: label/resize_CHNCXR_0466_1.png
#   inflating: label/resize_CHNCXR_0467_1.png
#   inflating: label/resize_CHNCXR_0468_1.png
#   inflating: label/resize_CHNCXR_0469_1.png
#   inflating: label/resize_CHNCXR_0470_1.png
#   inflating: label/resize_CHNCXR_0471_1.png
#   inflating: label/resize_CHNCXR_0472_1.png
#   inflating: label/resize_CHNCXR_0473_1.png
#   inflating: label/resize_CHNCXR_0474_1.png
#   inflating: label/resize_CHNCXR_0475_1.png
#   inflating: label/resize_CHNCXR_0476_1.png
#   inflating: label/resize_CHNCXR_0477_1.png
#   inflating: label/resize_CHNCXR_0478_1.png
#   inflating: label/resize_CHNCXR_0479_1.png
#   inflating: label/resize_CHNCXR_0480_1.png
#   inflating: label/resize_CHNCXR_0501_1.png
#   inflating: label/resize_CHNCXR_0503_1.png
#   inflating: label/resize_CHNCXR_0504_1.png
#   inflating: label/resize_CHNCXR_0506_1.png
#   inflating: label/resize_CHNCXR_0507_1.png
#   inflating: label/resize_CHNCXR_0508_1.png
#   inflating: label/resize_CHNCXR_0509_1.png
#   inflating: label/resize_CHNCXR_0510_1.png
#   inflating: label/resize_CHNCXR_0511_1.png
#   inflating: label/resize_CHNCXR_0512_1.png
#   inflating: label/resize_CHNCXR_0513_1.png
#   inflating: label/resize_CHNCXR_0514_1.png
#   inflating: label/resize_CHNCXR_0515_1.png
#   inflating: label/resize_CHNCXR_0516_1.png
#   inflating: label/resize_CHNCXR_0517_1.png
#   inflating: label/resize_CHNCXR_0518_1.png
#   inflating: label/resize_CHNCXR_0519_1.png
#   inflating: label/resize_CHNCXR_0520_1.png
#   inflating: label/resize_CHNCXR_0521_1.png
#   inflating: label/resize_CHNCXR_0522_1.png
#   inflating: label/resize_CHNCXR_0523_1.png
#   inflating: label/resize_CHNCXR_0524_1.png
#   inflating: label/resize_CHNCXR_0525_1.png
#   inflating: label/resize_CHNCXR_0526_1.png
#   inflating: label/resize_CHNCXR_0527_1.png
#   inflating: label/resize_CHNCXR_0528_1.png
#   inflating: label/resize_CHNCXR_0529_1.png
#   inflating: label/resize_CHNCXR_0530_1.png
#   inflating: label/resize_CHNCXR_0531_1.png
#   inflating: label/resize_CHNCXR_0532_1.png
#   inflating: label/resize_CHNCXR_0533_1.png
#   inflating: label/resize_CHNCXR_0534_1.png
#   inflating: label/resize_CHNCXR_0535_1.png
#   inflating: label/resize_CHNCXR_0536_1.png
#   inflating: label/resize_CHNCXR_0537_1.png
#   inflating: label/resize_CHNCXR_0538_1.png
#   inflating: label/resize_CHNCXR_0539_1.png
#   inflating: label/resize_CHNCXR_0540_1.png
#   inflating: label/resize_CHNCXR_0541_1.png
#   inflating: label/resize_CHNCXR_0542_1.png
#   inflating: label/resize_CHNCXR_0543_1.png
#   inflating: label/resize_CHNCXR_0544_1.png
#   inflating: label/resize_CHNCXR_0545_1.png
#   inflating: label/resize_CHNCXR_0546_1.png
#   inflating: label/resize_CHNCXR_0547_1.png
#   inflating: label/resize_CHNCXR_0548_1.png
#   inflating: label/resize_CHNCXR_0549_1.png
#   inflating: label/resize_CHNCXR_0550_1.png
#   inflating: label/resize_CHNCXR_0551_1.png
#   inflating: label/resize_CHNCXR_0552_1.png
#   inflating: label/resize_CHNCXR_0553_1.png
#   inflating: label/resize_CHNCXR_0554_1.png
#   inflating: label/resize_CHNCXR_0555_1.png
#   inflating: label/resize_CHNCXR_0556_1.png
#   inflating: label/resize_CHNCXR_0557_1.png
#   inflating: label/resize_CHNCXR_0558_1.png
#   inflating: label/resize_CHNCXR_0559_1.png
#   inflating: label/resize_CHNCXR_0566_1.png
#   inflating: label/resize_CHNCXR_0567_1.png
#   inflating: label/resize_CHNCXR_0568_1.png
#   inflating: label/resize_CHNCXR_0569_1.png
#   inflating: label/resize_CHNCXR_0570_1.png
#   inflating: label/resize_CHNCXR_0571_1.png
#   inflating: label/resize_CHNCXR_0572_1.png
#   inflating: label/resize_CHNCXR_0573_1.png
#   inflating: label/resize_CHNCXR_0574_1.png
#   inflating: label/resize_CHNCXR_0575_1.png
#   inflating: label/resize_CHNCXR_0576_1.png
#   inflating: label/resize_CHNCXR_0577_1.png
#   inflating: label/resize_CHNCXR_0578_1.png
#   inflating: label/resize_CHNCXR_0579_1.png
#   inflating: label/resize_CHNCXR_0580_1.png
#   inflating: label/resize_CHNCXR_0581_1.png
#   inflating: label/resize_CHNCXR_0582_1.png
#   inflating: label/resize_CHNCXR_0583_1.png
#   inflating: label/resize_CHNCXR_0584_1.png
#   inflating: label/resize_CHNCXR_0585_1.png
#   inflating: label/resize_CHNCXR_0586_1.png
#   inflating: label/resize_CHNCXR_0587_1.png
#   inflating: label/resize_CHNCXR_0588_1.png
#   inflating: label/resize_CHNCXR_0589_1.png
#   inflating: label/resize_CHNCXR_0590_1.png
#   inflating: label/resize_CHNCXR_0591_1.png
#   inflating: label/resize_CHNCXR_0592_1.png
#   inflating: label/resize_CHNCXR_0593_1.png
#   inflating: label/resize_CHNCXR_0594_1.png
#   inflating: label/resize_CHNCXR_0595_1.png
#   inflating: label/resize_CHNCXR_0596_1.png
#   inflating: label/resize_CHNCXR_0597_1.png
#   inflating: label/resize_CHNCXR_0598_1.png
#   inflating: label/resize_CHNCXR_0599_1.png
#   inflating: label/resize_CHNCXR_0600_1.png
#   inflating: label/resize_CHNCXR_0601_1.png
#   inflating: label/resize_CHNCXR_0602_1.png
#   inflating: label/resize_CHNCXR_0603_1.png
#   inflating: label/resize_CHNCXR_0604_1.png
#   inflating: label/resize_CHNCXR_0605_1.png
#   inflating: label/resize_CHNCXR_0606_1.png
#   inflating: label/resize_CHNCXR_0607_1.png
#   inflating: label/resize_CHNCXR_0608_1.png
#   inflating: label/resize_CHNCXR_0609_1.png
#   inflating: label/resize_CHNCXR_0610_1.png
#   inflating: label/resize_CHNCXR_0611_1.png
#   inflating: label/resize_CHNCXR_0612_1.png
#   inflating: label/resize_CHNCXR_0613_1.png
#   inflating: label/resize_CHNCXR_0614_1.png
#   inflating: label/resize_CHNCXR_0615_1.png
#   inflating: label/resize_CHNCXR_0616_1.png
#   inflating: label/resize_CHNCXR_0617_1.png
#   inflating: label/resize_CHNCXR_0618_1.png
#   inflating: label/resize_CHNCXR_0619_1.png
#   inflating: label/resize_CHNCXR_0620_1.png
#   inflating: label/resize_CHNCXR_0621_1.png
#   inflating: label/resize_CHNCXR_0622_1.png
#   inflating: label/resize_CHNCXR_0623_1.png
#   inflating: label/resize_CHNCXR_0624_1.png
#   inflating: label/resize_CHNCXR_0625_1.png
#   inflating: label/resize_CHNCXR_0626_1.png
#   inflating: label/resize_CHNCXR_0627_1.png
#   inflating: label/resize_CHNCXR_0628_1.png
#   inflating: label/resize_CHNCXR_0629_1.png
#   inflating: label/resize_CHNCXR_0630_1.png
#   inflating: label/resize_CHNCXR_0631_1.png
#   inflating: label/resize_CHNCXR_0632_1.png
#   inflating: label/resize_CHNCXR_0633_1.png
#   inflating: label/resize_CHNCXR_0634_1.png
#   inflating: label/resize_CHNCXR_0635_1.png
#   inflating: label/resize_CHNCXR_0636_1.png
#   inflating: label/resize_CHNCXR_0637_1.png
#   inflating: label/resize_CHNCXR_0638_1.png
#   inflating: label/resize_CHNCXR_0639_1.png
#   inflating: label/resize_CHNCXR_0640_1.png
#   inflating: label/resize_CHNCXR_0641_1.png
#   inflating: label/resize_CHNCXR_0642_1.png
#   inflating: label/resize_CHNCXR_0643_1.png
#   inflating: label/resize_CHNCXR_0644_1.png
#   inflating: label/resize_CHNCXR_0645_1.png
#   inflating: label/resize_CHNCXR_0646_1.png
#   inflating: label/resize_CHNCXR_0647_1.png
#   inflating: label/resize_CHNCXR_0648_1.png
#   inflating: label/resize_CHNCXR_0649_1.png
#   inflating: label/resize_CHNCXR_0650_1.png
#   inflating: label/resize_CHNCXR_0651_1.png
#   inflating: label/resize_CHNCXR_0652_1.png
#   inflating: label/resize_CHNCXR_0653_1.png
#   inflating: label/resize_CHNCXR_0654_1.png
#   inflating: label/resize_CHNCXR_0655_1.png
#   inflating: label/resize_CHNCXR_0656_1.png
#   inflating: label/resize_CHNCXR_0657_1.png
#   inflating: label/resize_CHNCXR_0658_1.png
#   inflating: label/resize_CHNCXR_0659_1.png
#   inflating: label/resize_CHNCXR_0660_1.png
#   inflating: label/resize_CHNCXR_0661_1.png
#   inflating: label/resize_CHNCXR_0662_1.png

# %%
#mount google drive to read data
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Data/Lung_Segmentation'
# Out:
# /content/drive/My Drive/Data/Lung_Segmentation

# %%
import os
import numpy as np

from skimage.io import imread
from skimage.transform import resize
from sklearn.model_selection import train_test_split

IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3

data_path = "./"

files = os.listdir(os.path.join(data_path, 'image'))
file_headers = []  #python list
for f in files:
    f1 = os.path.splitext(f)[0]
    file_headers.append(f1)
#print(file_headers)

X_all = np.zeros((len(file_headers), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
y_all = np.zeros((len(file_headers), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

count = 0
for fh in file_headers:
    f1 = os.path.join(data_path, 'image', '{}.png'.format(fh))
    l1 = os.path.join(data_path, 'label', '{}.png'.format(fh))
    
    img = imread(f1)[:,:,:IMG_CHANNELS]
    mask = imread(l1)
    mask = np.expand_dims(mask, axis=-1)

    X_all[count] = img
    y_all[count] = mask
    
    count += 1

# %% [markdown]
# **딥러닝을 위한 데이터 전처리**

# %%
X_all = X_all.astype('float32') / 255.
y_all = y_all.astype('float32')

# %% [markdown]
# **학습, 검증, 테스트 데이터 셋으로 분리**

# %%
# fix random seed for reproductibility
seed = 7
np.random.seed(seed)

X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, test_size=0.2)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2)

# %%
print('X_train',X_train.shape)
print('X_valid',X_valid.shape)
print('X_test',X_test.shape)
print('y_train',y_train.shape)
print('y_valid',y_valid.shape)
print('y_test',y_test.shape)
# Out:
# X_train (361, 256, 256, 3)
# X_valid (91, 256, 256, 3)
# X_test (114, 256, 256, 3)
# y_train (361, 256, 256, 1)
# y_valid (91, 256, 256, 1)
# y_test (114, 256, 256, 1)

# %% [markdown]
# ## STEP 2: 데이터 살펴보기

# %%
import matplotlib.pyplot as plt

def plotTrainData(a,b,c):
    for i in range(3):
        ix = np.random.randint(0, len(a))
        plt.subplot(1,2,1)
        plt.title("X_" + c)
        plt.imshow(a[ix])
        plt.axis('off')
        plt.subplot(1,2,2)
        plt.title("y_" + c)
        plt.imshow(np.squeeze(b[ix]), 'gray') # squeeze: 1차원 축 제거
        plt.axis('off')
        plt.show()
        
plotTrainData(X_train,y_train, 'train')
plotTrainData(X_valid,y_valid, 'valid')
plotTrainData(X_test,y_test, 'test')

# %% [markdown]
# ## STEP 3: VGG16 네트워크 다시 보기
# ![대체 텍스트](https://neurohive.io/wp-content/uploads/2018/11/vgg16-1-e1542731207177.png)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import Add
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model

def vgg16():
    inputs = Input(shape=(256, 256, 3,), name="VGGInput")
    
    conv1_1 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    bn1_1 = BatchNormalization()(conv1_1)
    conv1_2 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(bn1_1)
    bn1_2 = BatchNormalization()(conv1_2)
    pool_1 = MaxPool2D(padding='same')(bn1_2)

    #(128,128)
    conv2_1 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(pool_1)
    bn2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(bn2_1)
    bn2_2 = BatchNormalization()(conv2_2)
    pool_2 = MaxPool2D(padding='same')(bn2_2)
    
    #(64, 64)
    conv3_1 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(pool_2)
    bn3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_1)
    bn3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_2)
    bn3_3 = BatchNormalization()(conv3_3)
    pool_3 = MaxPool2D(padding='same')(bn3_3)
    
    #(32, 32)
    conv4_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_3)
    bn4_1 = BatchNormalization()(conv4_1)
    conv4_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_1)
    bn4_2 = BatchNormalization()(conv4_2)
    conv4_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_2)
    bn4_3 = BatchNormalization()(conv4_3)
    pool_4 = MaxPool2D(padding='same')(bn4_3)
    
    #(16, 16)
    conv5_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_4)
    bn5_1 = BatchNormalization()(conv5_1)
    conv5_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_1)
    bn5_2 = BatchNormalization()(conv5_2)
    conv5_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_2)
    bn5_3 = BatchNormalization()(conv5_3)
    pool_5 = MaxPool2D(padding='same')(bn5_3)

    #(8, 8)
    x = Conv2D(filters=4096, kernel_size=(8,8), padding='valid', activation=relu)(pool_5)
    x = Flatten()(x)
    x = Dense(4096, activation=relu)(x)
    pred = Dense(1000, activation=softmax)(x)
        
    return Model(inputs=inputs, outputs=pred)

# %% [markdown]
# **FCN 32 - first fully convolutional network**
# ![image interpolation](https://matplotlib.org/_images/interpolation_methods.png)
# **image interpolation**

# %% [markdown]
# ## STEP 4: 첫 번째 영상분할 모델 (FCN32s)

# %%
from tensorflow.keras.layers import Activation

def fcn32s():
    inputs = Input(shape=(256, 256, 3,), name="FCNInput")
    
    conv1_1 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    bn1_1 = BatchNormalization()(conv1_1)
    conv1_2 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(bn1_1)
    bn1_2 = BatchNormalization()(conv1_2)
    pool_1 = MaxPool2D(padding='same')(bn1_2)

    #(128,128)
    conv2_1 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(pool_1)
    bn2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(bn2_1)
    bn2_2 = BatchNormalization()(conv2_2)
    pool_2 = MaxPool2D(padding='same')(bn2_2)
    
    #(64, 64)
    conv3_1 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(pool_2)
    bn3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_1)
    bn3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_2)
    bn3_3 = BatchNormalization()(conv3_3)
    pool_3 = MaxPool2D(padding='same')(bn3_3)
    
    #(32, 32)
    conv4_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_3)
    bn4_1 = BatchNormalization()(conv4_1)
    conv4_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_1)
    bn4_2 = BatchNormalization()(conv4_2)
    conv4_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_2)
    bn4_3 = BatchNormalization()(conv4_3)
    pool_4 = MaxPool2D(padding='same')(bn4_3)
    
    #(16, 16)
    conv5_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_4)
    bn5_1 = BatchNormalization()(conv5_1)
    conv5_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_1)
    bn5_2 = BatchNormalization()(conv5_2)
    conv5_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_2)
    bn5_3 = BatchNormalization()(conv5_3)
    pool_5 = MaxPool2D(padding='same')(bn5_3)

    #x = Conv2D(filters=4096, kernel_size=(8,8), padding='valid', activation=relu)(pool_5)
    #x = Flatten()(x)
    #x = Dense(4096, activation=relu)(x)
    #pred = Dense(1000, activation=softmax)(x)
        
    conv_t1 = UpSampling2D(size = (32,32))(pool_5) # UpSampling2D??
    conv_t2 = Conv2D(1, (1,1), padding="valid", activation="relu")(conv_t1)
    # conv_t2 = Conv2D(2, (1,1), padding="valid", activation="relu")(conv_t1)

    pred = Activation('sigmoid')(conv_t2)
    # pred = Activation('softmax')(conv_t2)

    return Model(inputs=inputs, outputs=pred)

# %% [markdown]
# ![대체 텍스트](https://jinglescode.github.io/assets/img/posts/unet-03.webp)
# ![대체 텍스트](https://miro.medium.com/max/875/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + 1) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
from tensorflow.keras.optimizers import SGD

# build the model
model = fcn32s()
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss=dice_coef_loss, optimizer=sgd, metrics=[dice_coef])

# fix random seed for reproductibility
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# FIT THE MODEL - OPTIMIZATION
hist = model.fit(X_train, y_train,validation_data=(X_valid, y_valid), epochs=20, batch_size=8, verbose=1)
model.save('fcn-32s.h5')

# 학습과정 살펴보기
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['dice_coef'], 'b', label='train dice_coef')
acc_ax.plot(hist.history['val_dice_coef'], 'g', label='val dice_coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('dice_coef')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/20
# 46/46 [==============================] - 13s 256ms/step - loss: 0.4897 - dice_coef: 0.5104 - val_loss: 0.6625 - val_dice_coef: 0.3388
# Epoch 2/20
# 46/46 [==============================] - 11s 249ms/step - loss: 0.4763 - dice_coef: 0.5240 - val_loss: 0.6625 - val_dice_coef: 0.3388
# Epoch 3/20
# 46/46 [==============================] - 12s 252ms/step - loss: 0.4752 - dice_coef: 0.5274 - val_loss: 0.6625 - val_dice_coef: 0.3388
# Epoch 4/20
# 46/46 [==============================] - 12s 263ms/step - loss: 0.4743 - dice_coef: 0.5241 - val_loss: 0.6625 - val_dice_coef: 0.3388
# Epoch 5/20
# 46/46 [==============================] - 12s 266ms/step - loss: 0.4779 - dice_coef: 0.5217 - val_loss: 0.6625 - val_dice_coef: 0.3388
# Epoch 6/20
# 46/46 [==============================] - 12s 269ms/step - loss: 0.4740 - dice_coef: 0.5275 - val_loss: 0.6625 - val_dice_coef: 0.3388
# Epoch 7/20
# 46/46 [==============================] - 12s 270ms/step - loss: 0.4737 - dice_coef: 0.5268 - val_loss: 0.6176 - val_dice_coef: 0.3843
# Epoch 8/20
# 46/46 [==============================] - 12s 268ms/step - loss: 0.4736 - dice_coef: 0.5266 - val_loss: 0.5424 - val_dice_coef: 0.4597
# Epoch 9/20
# 46/46 [==============================] - 12s 266ms/step - loss: 0.4728 - dice_coef: 0.5285 - val_loss: 0.5256 - val_dice_coef: 0.4764
# Epoch 10/20
# 46/46 [==============================] - 12s 265ms/step - loss: 0.4726 - dice_coef: 0.5265 - val_loss: 0.4857 - val_dice_coef: 0.5162
# Epoch 11/20
# 46/46 [==============================] - 12s 258ms/step - loss: 0.4721 - dice_coef: 0.5286 - val_loss: 0.4801 - val_dice_coef: 0.5219
# Epoch 12/20
# 46/46 [==============================] - 12s 266ms/step - loss: 0.4723 - dice_coef: 0.5252 - val_loss: 0.4743 - val_dice_coef: 0.5276
# Epoch 13/20
# 46/46 [==============================] - 12s 261ms/step - loss: 0.4720 - dice_coef: 0.5270 - val_loss: 0.4738 - val_dice_coef: 0.5281
# Epoch 14/20
# 46/46 [==============================] - 12s 261ms/step - loss: 0.4721 - dice_coef: 0.5268 - val_loss: 0.4734 - val_dice_coef: 0.5284
# Epoch 15/20
# 46/46 [==============================] - 12s 267ms/step - loss: 0.4718 - dice_coef: 0.5287 - val_loss: 0.4730 - val_dice_coef: 0.5288
# Epoch 16/20
# 46/46 [==============================] - 12s 267ms/step - loss: 0.4719 - dice_coef: 0.5292 - val_loss: 0.4729 - val_dice_coef: 0.5289
# Epoch 17/20
# 46/46 [==============================] - 12s 260ms/step - loss: 0.4718 - dice_coef: 0.5267 - val_loss: 0.4728 - val_dice_coef: 0.5291
# Epoch 18/20
# 46/46 [==============================] - 12s 260ms/step - loss: 0.4715 - dice_coef: 0.5309 - val_loss: 0.4728 - val_dice_coef: 0.5290
# Epoch 19/20
# 46/46 [==============================] - 12s 267ms/step - loss: 0.4716 - dice_coef: 0.5266 - val_loss: 0.4727 - val_dice_coef: 0.5292
# Epoch 20/20
# 46/46 [==============================] - 12s 267ms/step - loss: 0.4713 - dice_coef: 0.5289 - val_loss: 0.4726 - val_dice_coef: 0.5292

# %% [markdown]
# ## STEP 5: 결과 확인하기

# %%
import matplotlib.pyplot as plt

def plotPredictions(X_train_, y_train_, X_valid_, y_valid_, X_test_, y_test_, simpleFCN):
    model = simpleFCN     

    ix = np.random.randint(0, len(X_train_))
    input_ = X_train_[ix:ix+1]
    mask_ = y_train_[ix:ix+1]
    preds_train = model.predict(input_)
    preds_train_t = (preds_train > 0.5).astype(np.uint8)
    plt.figure(figsize=(10,10))
    plt.subplot(1,3,1)
    plt.title("X_train")
    plt.axis('off')
    plt.imshow(input_[0])
    plt.subplot(1,3,2)
    plt.title("Y_train")
    plt.axis('off')
    plt.imshow(mask_[0][:,:,0], 'gray')
    plt.subplot(1,3,3)
    ret = model.evaluate(input_, mask_)
    plt.title("Prediction: %.4f" % (ret[1]))
    plt.axis('off')
    plt.imshow(preds_train_t[0][:,:,0], 'gray')
    plt.show()
    
    ix = np.random.randint(0, len(X_valid_))
    input_ = X_valid_[ix:ix+1]
    mask_ = y_valid_[ix:ix+1]
    preds_valid = model.predict(input_)
    preds_valid_t = (preds_valid > 0.5).astype(np.uint8)
    plt.figure(figsize=(10,10))
    plt.subplot(1,3,1)
    plt.title("X_valid")
    plt.axis('off')
    plt.imshow(input_[0])
    plt.subplot(1,3,2)
    plt.title("Y_valid")
    plt.axis('off')
    plt.imshow(mask_[0][:,:,0], 'gray')
    plt.subplot(1,3,3)
    ret = model.evaluate(input_, mask_)
    plt.title("Prediction: %.4f" % (ret[1]))
    plt.axis('off')
    plt.imshow(preds_valid_t[0][:,:,0], 'gray')
    plt.show()
    
    ix = np.random.randint(0, len(X_test_))
    input_ = X_test_[ix:ix+1]
    mask_ = y_test_[ix:ix+1]
    preds_test = model.predict(input_)
    preds_test_t = (preds_test > 0.5).astype(np.uint8)
    plt.figure(figsize=(10,10))
    plt.subplot(1,3,1)
    plt.title("X_test")
    plt.axis('off')
    plt.imshow(input_[0])
    plt.subplot(1,3,2)
    plt.title("Y_test")
    plt.axis('off')
    plt.imshow(mask_[0][:,:,0], 'gray')
    plt.subplot(1,3,3)
    ret = model.evaluate(input_, mask_)
    plt.title("Prediction: %.4f" % (ret[1]))
    plt.axis('off')
    plt.imshow(preds_test_t[0][:,:,0], 'gray')
    plt.show()

# %%
plotPredictions(X_train, y_train, X_valid, y_valid, X_test, y_test, model)
# Out:
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4551 - dice_coef: 0.5449
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4576 - dice_coef: 0.5424
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6010 - dice_coef: 0.3990

# %% [markdown]
# ## STEP 6: 두 번째 모델 (FCN8s)
# **Skip Connection**
# ![대체 텍스트](http://deeplearning.net/tutorial/_images/fcn_schema.png)

# %%
def fcn8s():
    inputs = Input(shape=(256, 256, 3,), name="FCNInput")
    
    conv1_1 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    bn1_1 = BatchNormalization()(conv1_1)
    conv1_2 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(bn1_1)
    bn1_2 = BatchNormalization()(conv1_2)
    pool_1 = MaxPool2D(padding='same')(bn1_2)

    #(128,128)
    conv2_1 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(pool_1)
    bn2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(bn2_1)
    bn2_2 = BatchNormalization()(conv2_2)
    pool_2 = MaxPool2D(padding='same')(bn2_2)
    
    #(64, 64)
    conv3_1 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(pool_2)
    bn3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_1)
    bn3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_2)
    bn3_3 = BatchNormalization()(conv3_3)
    pool_3 = MaxPool2D(padding='same')(bn3_3)
    
    #(32, 32)
    conv4_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_3)
    bn4_1 = BatchNormalization()(conv4_1)
    conv4_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_1)
    bn4_2 = BatchNormalization()(conv4_2)
    conv4_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_2)
    bn4_3 = BatchNormalization()(conv4_3)
    pool_4 = MaxPool2D(padding='same')(bn4_3)
    
    #(16, 16)
    conv5_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_4)
    bn5_1 = BatchNormalization()(conv5_1)
    conv5_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_1)
    bn5_2 = BatchNormalization()(conv5_2)
    conv5_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_2)
    bn5_3 = BatchNormalization()(conv5_3)
    pool_5 = MaxPool2D(padding='same')(bn5_3)

    #(8, 8)
    #x = Conv2D(filters=4096, kernel_size=(8,8), padding='valid', activation=relu)(pool_5)
    #x = Flatten()(x)
    #x = Dense(4096, activation=relu)(x)
    #pred = Dense(1000, activation=softmax)(x)
    
    #(8, 8)
    conv6 = Conv2D(2048, (1,1), padding="valid", activation="relu")(pool_5)
    conv7 = Conv2D(2048, (1,1), padding="valid", activation="relu")(conv6)
    conv8 = Conv2D(1, (1,1), padding="valid", activation="relu")(conv7)
    
    #(16, 16)
    score_pool4 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_4)
    conv_t1 = UpSampling2D(size = (2,2))(conv8)     
    fuse_1 = Add()([conv_t1,score_pool4])

    #(32, 32)
    score_pool3 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_3)
    conv_t2 = UpSampling2D(size = (2,2))(fuse_1)
    fuse_2 = Add()([conv_t2,score_pool3])
   
    conv_t3 = UpSampling2D(size = (8,8))(fuse_2)
    
    pred = Activation('sigmoid')(conv_t3)
    
    return Model(inputs=inputs, outputs=pred)

# %%
# build the model
model = fcn8s()
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss=dice_coef_loss, optimizer=sgd, metrics=[dice_coef])

# fix random seed for reproductibility
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# FIT THE MODEL - OPTIMIZATION
hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=20, batch_size=8, verbose=1)
model.save('fcn-8s.h5')

# 학습과정 살펴보기
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['dice_coef'], 'b', label='train dice_coef')
acc_ax.plot(hist.history['val_dice_coef'], 'g', label='val dice_coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('dice_coef')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/20
# 46/46 [==============================] - 11s 208ms/step - loss: 0.4716 - dice_coef: 0.5289 - val_loss: 0.6534 - val_dice_coef: 0.3479
# Epoch 2/20
# 46/46 [==============================] - 10s 209ms/step - loss: 0.4504 - dice_coef: 0.5500 - val_loss: 0.6244 - val_dice_coef: 0.3771
# Epoch 3/20
# 46/46 [==============================] - 9s 197ms/step - loss: 0.4483 - dice_coef: 0.5543 - val_loss: 0.5891 - val_dice_coef: 0.4125
# Epoch 4/20
# 46/46 [==============================] - 10s 211ms/step - loss: 0.4470 - dice_coef: 0.5508 - val_loss: 0.6327 - val_dice_coef: 0.3689
# Epoch 5/20
# 46/46 [==============================] - 10s 211ms/step - loss: 0.4542 - dice_coef: 0.5455 - val_loss: 0.5684 - val_dice_coef: 0.4333
# Epoch 6/20
# 46/46 [==============================] - 10s 212ms/step - loss: 0.4471 - dice_coef: 0.5543 - val_loss: 0.5845 - val_dice_coef: 0.4170
# Epoch 7/20
# 46/46 [==============================] - 10s 213ms/step - loss: 0.4458 - dice_coef: 0.5546 - val_loss: 0.6530 - val_dice_coef: 0.3483
# Epoch 8/20
# 46/46 [==============================] - 10s 214ms/step - loss: 0.4455 - dice_coef: 0.5547 - val_loss: 0.5932 - val_dice_coef: 0.4094
# Epoch 9/20
# 46/46 [==============================] - 10s 214ms/step - loss: 0.4446 - dice_coef: 0.5566 - val_loss: 0.6004 - val_dice_coef: 0.4020
# Epoch 10/20
# 46/46 [==============================] - 10s 214ms/step - loss: 0.4443 - dice_coef: 0.5547 - val_loss: 0.5077 - val_dice_coef: 0.4954
# Epoch 11/20
# 46/46 [==============================] - 10s 215ms/step - loss: 0.4439 - dice_coef: 0.5568 - val_loss: 0.5154 - val_dice_coef: 0.4869
# Epoch 12/20
# 46/46 [==============================] - 9s 203ms/step - loss: 0.4441 - dice_coef: 0.5531 - val_loss: 0.4499 - val_dice_coef: 0.5525
# Epoch 13/20
# 46/46 [==============================] - 10s 215ms/step - loss: 0.4433 - dice_coef: 0.5557 - val_loss: 0.4462 - val_dice_coef: 0.5560
# Epoch 14/20
# 46/46 [==============================] - 10s 216ms/step - loss: 0.4433 - dice_coef: 0.5557 - val_loss: 0.4453 - val_dice_coef: 0.5569
# Epoch 15/20
# 46/46 [==============================] - 10s 216ms/step - loss: 0.4431 - dice_coef: 0.5572 - val_loss: 0.4447 - val_dice_coef: 0.5575
# Epoch 16/20
# 46/46 [==============================] - 10s 216ms/step - loss: 0.4431 - dice_coef: 0.5580 - val_loss: 0.4434 - val_dice_coef: 0.5587
# Epoch 17/20
# 46/46 [==============================] - 10s 217ms/step - loss: 0.4431 - dice_coef: 0.5555 - val_loss: 0.4449 - val_dice_coef: 0.5572
# Epoch 18/20
# 46/46 [==============================] - 9s 204ms/step - loss: 0.4426 - dice_coef: 0.5597 - val_loss: 0.4440 - val_dice_coef: 0.5581
# Epoch 19/20
# 46/46 [==============================] - 9s 205ms/step - loss: 0.4426 - dice_coef: 0.5554 - val_loss: 0.4450 - val_dice_coef: 0.5572
# Epoch 20/20
# 46/46 [==============================] - 9s 205ms/step - loss: 0.4423 - dice_coef: 0.5579 - val_loss: 0.4438 - val_dice_coef: 0.5583
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
plotPredictions(X_train, y_train, X_valid, y_valid, X_test, y_test, model)
# Out:
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4317 - dice_coef: 0.5683
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4312 - dice_coef: 0.5688
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5705 - dice_coef: 0.4295

# %% [markdown]
# ## STEP 6-1: 두 번째 모델 (FCN8s)의 개선시도 -> (FCN2s)
# **Skip Connection**

# %%
def fcn2s():
    inputs = Input(shape=(256, 256, 3,), name="FCNInput")
    
    conv1_1 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    bn1_1 = BatchNormalization()(conv1_1)
    conv1_2 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(bn1_1)
    bn1_2 = BatchNormalization()(conv1_2)
    pool_1 = MaxPool2D(padding='same')(bn1_2)

    #(128,128)
    conv2_1 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(pool_1)
    bn2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(bn2_1)
    bn2_2 = BatchNormalization()(conv2_2)
    pool_2 = MaxPool2D(padding='same')(bn2_2)
    
    #(64, 64)
    conv3_1 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(pool_2)
    bn3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_1)
    bn3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_2)
    bn3_3 = BatchNormalization()(conv3_3)
    pool_3 = MaxPool2D(padding='same')(bn3_3)
    
    #(32, 32)
    conv4_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_3)
    bn4_1 = BatchNormalization()(conv4_1)
    conv4_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_1)
    bn4_2 = BatchNormalization()(conv4_2)
    conv4_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_2)
    bn4_3 = BatchNormalization()(conv4_3)
    pool_4 = MaxPool2D(padding='same')(bn4_3)
    
    #(16, 16)
    conv5_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_4)
    bn5_1 = BatchNormalization()(conv5_1)
    conv5_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_1)
    bn5_2 = BatchNormalization()(conv5_2)
    conv5_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_2)
    bn5_3 = BatchNormalization()(conv5_3)
    pool_5 = MaxPool2D(padding='same')(bn5_3)

    #(8, 8)
    #x = Conv2D(filters=4096, kernel_size=(8,8), padding='valid', activation=relu)(pool_5)
    #x = Flatten()(x)
    #x = Dense(4096, activation=relu)(x)
    #pred = Dense(1000, activation=softmax)(x)
    
    #(8, 8)
    conv6 = Conv2D(2048, (1,1), padding="valid", activation="relu")(pool_5)
    conv7 = Conv2D(2048, (1,1), padding="valid", activation="relu")(conv6)
    conv8 = Conv2D(1, (1,1), padding="valid", activation="relu")(conv7)

    #(16, 16)
    score_pool4 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_4)
    conv_t1 = UpSampling2D(size = (2,2))(conv8)    
    fuse_1 = Add()([conv_t1,score_pool4])

    #(32, 32)
    score_pool3 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_3)
    conv_t2 = UpSampling2D(size = (2,2))(fuse_1)
    fuse_2 = Add()([conv_t2,score_pool3])
  
    # fcn8s에서 추가된 소스 코드
    #(64, 64)
    score_pool2 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_2)
    conv_t3 = UpSampling2D(size = (2,2))(fuse_2)
    fuse_3 = Add()([conv_t3,score_pool2])

    #(128, 128)
    score_pool1 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_1)
    conv_t4 = UpSampling2D(size = (2,2))(fuse_3)
    fuse_4 = Add()([conv_t4,score_pool1])
      
    conv_t5 = UpSampling2D(size = (2,2))(fuse_4)
    
    pred = Activation('sigmoid')(conv_t5)
    
    return Model(inputs=inputs, outputs=pred)

# %%
# build the model
model = fcn2s()
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss=dice_coef_loss, optimizer=sgd, metrics=[dice_coef])

# fix random seed for reproductibility
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# FIT THE MODEL - OPTIMIZATION
hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=20, batch_size=8, verbose=1)
model.save('fcn-2s.h5')

# 학습과정 살펴보기
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['dice_coef'], 'b', label='train dice_coef')
acc_ax.plot(hist.history['val_dice_coef'], 'g', label='val dice_coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('dice_coef')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/20
# 46/46 [==============================] - 11s 215ms/step - loss: 0.5011 - dice_coef: 0.4998 - val_loss: 0.6598 - val_dice_coef: 0.3415
# Epoch 2/20
# 46/46 [==============================] - 10s 224ms/step - loss: 0.4544 - dice_coef: 0.5460 - val_loss: 0.6607 - val_dice_coef: 0.3406
# Epoch 3/20
# 46/46 [==============================] - 10s 226ms/step - loss: 0.4504 - dice_coef: 0.5522 - val_loss: 0.6485 - val_dice_coef: 0.3528
# Epoch 4/20
# 46/46 [==============================] - 10s 212ms/step - loss: 0.4477 - dice_coef: 0.5503 - val_loss: 0.6532 - val_dice_coef: 0.3482
# Epoch 5/20
# 46/46 [==============================] - 10s 210ms/step - loss: 0.4513 - dice_coef: 0.5483 - val_loss: 0.6330 - val_dice_coef: 0.3684
# Epoch 6/20
# 46/46 [==============================] - 10s 220ms/step - loss: 0.4462 - dice_coef: 0.5552 - val_loss: 0.6476 - val_dice_coef: 0.3539
# Epoch 7/20
# 46/46 [==============================] - 10s 220ms/step - loss: 0.4452 - dice_coef: 0.5552 - val_loss: 0.6569 - val_dice_coef: 0.3445
# Epoch 8/20
# 46/46 [==============================] - 9s 207ms/step - loss: 0.4450 - dice_coef: 0.5552 - val_loss: 0.6500 - val_dice_coef: 0.3514
# Epoch 9/20
# 46/46 [==============================] - 10s 219ms/step - loss: 0.4443 - dice_coef: 0.5570 - val_loss: 0.6490 - val_dice_coef: 0.3525
# Epoch 10/20
# 46/46 [==============================] - 10s 220ms/step - loss: 0.4439 - dice_coef: 0.5551 - val_loss: 0.6118 - val_dice_coef: 0.3904
# Epoch 11/20
# 46/46 [==============================] - 10s 221ms/step - loss: 0.4435 - dice_coef: 0.5572 - val_loss: 0.5367 - val_dice_coef: 0.4659
# Epoch 12/20
# 46/46 [==============================] - 10s 210ms/step - loss: 0.4436 - dice_coef: 0.5536 - val_loss: 0.4587 - val_dice_coef: 0.5439
# Epoch 13/20
# 46/46 [==============================] - 10s 209ms/step - loss: 0.4430 - dice_coef: 0.5560 - val_loss: 0.4546 - val_dice_coef: 0.5478
# Epoch 14/20
# 46/46 [==============================] - 10s 221ms/step - loss: 0.4432 - dice_coef: 0.5559 - val_loss: 0.4497 - val_dice_coef: 0.5527
# Epoch 15/20
# 46/46 [==============================] - 10s 221ms/step - loss: 0.4428 - dice_coef: 0.5575 - val_loss: 0.4478 - val_dice_coef: 0.5544
# Epoch 16/20
# 46/46 [==============================] - 10s 208ms/step - loss: 0.4429 - dice_coef: 0.5583 - val_loss: 0.4462 - val_dice_coef: 0.5560
# Epoch 17/20
# 46/46 [==============================] - 10s 208ms/step - loss: 0.4428 - dice_coef: 0.5559 - val_loss: 0.4438 - val_dice_coef: 0.5583
# Epoch 18/20
# 46/46 [==============================] - 10s 220ms/step - loss: 0.4424 - dice_coef: 0.5599 - val_loss: 0.4445 - val_dice_coef: 0.5577
# Epoch 19/20
# 46/46 [==============================] - 10s 220ms/step - loss: 0.4424 - dice_coef: 0.5556 - val_loss: 0.4432 - val_dice_coef: 0.5590
# Epoch 20/20
# 46/46 [==============================] - 10s 221ms/step - loss: 0.4420 - dice_coef: 0.5583 - val_loss: 0.4428 - val_dice_coef: 0.5593
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
plotPredictions(X_train, y_train, X_valid, y_valid, X_test, y_test, model)
# Out:
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4311 - dice_coef: 0.5689
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4295 - dice_coef: 0.5705
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5714 - dice_coef: 0.4286

# %% [markdown]
# ## STEP 7: 세 번째 모델 (FCN8s with deconvolution)
# **deconvolution**
# ![대체 텍스트](https://miro.medium.com/max/1086/1*AbCrAqPBfkqGRdhKtiZQqA.png)

# %%
def fcn8s_deconv():
    inputs = Input(shape=(256, 256, 3,), name="FCNInput")
    
    conv1_1 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(inputs)
    bn1_1 = BatchNormalization()(conv1_1)
    conv1_2 = Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu')(bn1_1)
    bn1_2 = BatchNormalization()(conv1_2)
    pool_1 = MaxPool2D(padding='same')(bn1_2)

    #(128,128)
    conv2_1 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(pool_1)
    bn2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu')(bn2_1)
    bn2_2 = BatchNormalization()(conv2_2)
    pool_2 = MaxPool2D(padding='same')(bn2_2)
    
    #(64, 64)
    conv3_1 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(pool_2)
    bn3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_1)
    bn3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu')(bn3_2)
    bn3_3 = BatchNormalization()(conv3_3)
    pool_3 = MaxPool2D(padding='same')(bn3_3)
    
    #(32, 32)
    conv4_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_3)
    bn4_1 = BatchNormalization()(conv4_1)
    conv4_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_1)
    bn4_2 = BatchNormalization()(conv4_2)
    conv4_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn4_2)
    bn4_3 = BatchNormalization()(conv4_3)
    pool_4 = MaxPool2D(padding='same')(bn4_3)
    
    #(16, 16)
    conv5_1 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(pool_4)
    bn5_1 = BatchNormalization()(conv5_1)
    conv5_2 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_1)
    bn5_2 = BatchNormalization()(conv5_2)
    conv5_3 = Conv2D(filters=512, kernel_size=(3,3), padding='same', activation='relu')(bn5_2)
    bn5_3 = BatchNormalization()(conv5_3)
    pool_5 = MaxPool2D(padding='same')(bn5_3)

    #(8, 8)
    #x = Conv2D(filters=4096, kernel_size=(8,8), padding='valid', activation=relu)(pool_5)
    #x = Flatten()(x)
    #x = Dense(4096, activation=relu)(x)
    #pred = Dense(1000, activation=softmax)(x)
    
    #(8, 8)
    conv6 = Conv2D(2048, (1,1), padding="valid", activation="relu")(pool_5)
    conv7 = Conv2D(2048, (1,1), padding="valid", activation="relu")(conv6)
    conv8 = Conv2D(1, (1,1), padding="valid", activation="relu")(conv7)
 
    #(16, 16)
    score_pool4 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_4)
    
    conv_t1 = Conv2DTranspose(1, kernel_size=(2,2), strides=(2,2), padding="same")(conv8)
    conv_t1 = Conv2D(1, (3, 3), activation='relu', padding='same')(conv_t1)
    conv_t1 = BatchNormalization()(conv_t1)
    conv_t1 = Conv2D(1, (3, 3), activation='relu', padding='same')(conv_t1)
    conv_t1 = BatchNormalization()(conv_t1)
    
    fuse_1 = Add()([conv_t1,score_pool4])

    #(32, 32)
    score_pool3 = Conv2D(1, (1,1), padding="valid", activation="relu")(pool_3)
    
    conv_t2 = Conv2DTranspose(1, kernel_size=(2,2), strides=(2,2),padding="same")(fuse_1)
    conv_t2 = Conv2D(1, (3, 3), activation='relu', padding='same')(conv_t2)
    conv_t2 = BatchNormalization()(conv_t2)
    conv_t2 = Conv2D(1, (3, 3), activation='relu', padding='same')(conv_t2)
    conv_t2 = BatchNormalization()(conv_t2)
    
    fuse_2 = Add()([conv_t2,score_pool3])

    #(32, 32) x 8 = 256
    conv_t3 = Conv2DTranspose(1, kernel_size=(8,8), strides=(8,8), padding="same")(fuse_2)
    conv_t3 = Conv2D(1, (3, 3), activation='relu', padding='same')(conv_t3)
    conv_t3 = BatchNormalization()(conv_t3)
    conv_t3 = Conv2D(1, (3, 3), activation='relu', padding='same')(conv_t3)
    conv_t3 = BatchNormalization()(conv_t3)
    
    pred = Activation('sigmoid')(conv_t3)
    
    return Model(inputs=inputs, outputs=pred)

# %%
# build the model
model = fcn8s_deconv()
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss=dice_coef_loss, optimizer=sgd, metrics=[dice_coef])

# fix random seed for reproductibility
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# FIT THE MODEL - OPTIMIZATION
hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=20, batch_size=8, verbose=1)
model.save('fcn-8s_deconv.h5')

# 학습과정 살펴보기
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['dice_coef'], 'b', label='train dice_coef')
acc_ax.plot(hist.history['val_dice_coef'], 'g', label='val dice_coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('dice_coef')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/20
# 46/46 [==============================] - 12s 222ms/step - loss: 0.5158 - dice_coef: 0.4859 - val_loss: 0.6527 - val_dice_coef: 0.3486
# Epoch 2/20
# 46/46 [==============================] - 10s 225ms/step - loss: 0.3792 - dice_coef: 0.6222 - val_loss: 0.6680 - val_dice_coef: 0.3332
# Epoch 3/20
# 46/46 [==============================] - 10s 228ms/step - loss: 0.2843 - dice_coef: 0.7162 - val_loss: 0.7342 - val_dice_coef: 0.2666
# Epoch 4/20
# 46/46 [==============================] - 10s 215ms/step - loss: 0.2183 - dice_coef: 0.7775 - val_loss: 0.8115 - val_dice_coef: 0.1889
# Epoch 5/20
# 46/46 [==============================] - 10s 214ms/step - loss: 0.2049 - dice_coef: 0.7958 - val_loss: 0.8644 - val_dice_coef: 0.1359
# Epoch 6/20
# 46/46 [==============================] - 10s 211ms/step - loss: 0.1565 - dice_coef: 0.8443 - val_loss: 0.9089 - val_dice_coef: 0.0912
# Epoch 7/20
# 46/46 [==============================] - 10s 210ms/step - loss: 0.1356 - dice_coef: 0.8649 - val_loss: 0.9329 - val_dice_coef: 0.0671
# Epoch 8/20
# 46/46 [==============================] - 10s 222ms/step - loss: 0.1232 - dice_coef: 0.8763 - val_loss: 0.9469 - val_dice_coef: 0.0531
# Epoch 9/20
# 46/46 [==============================] - 10s 222ms/step - loss: 0.1133 - dice_coef: 0.8864 - val_loss: 0.8526 - val_dice_coef: 0.1481
# Epoch 10/20
# 46/46 [==============================] - 10s 211ms/step - loss: 0.1071 - dice_coef: 0.8922 - val_loss: 0.7542 - val_dice_coef: 0.2486
# Epoch 11/20
# 46/46 [==============================] - 10s 224ms/step - loss: 0.1030 - dice_coef: 0.8974 - val_loss: 0.3531 - val_dice_coef: 0.6492
# Epoch 12/20
# 46/46 [==============================] - 10s 213ms/step - loss: 0.0959 - dice_coef: 0.9032 - val_loss: 0.1832 - val_dice_coef: 0.8186
# Epoch 13/20
# 46/46 [==============================] - 10s 213ms/step - loss: 0.0919 - dice_coef: 0.9077 - val_loss: 0.2344 - val_dice_coef: 0.7678
# Epoch 14/20
# 46/46 [==============================] - 10s 213ms/step - loss: 0.0878 - dice_coef: 0.9122 - val_loss: 0.1210 - val_dice_coef: 0.8809
# Epoch 15/20
# 46/46 [==============================] - 10s 225ms/step - loss: 0.0854 - dice_coef: 0.9146 - val_loss: 0.1204 - val_dice_coef: 0.8815
# Epoch 16/20
# 46/46 [==============================] - 10s 212ms/step - loss: 0.0831 - dice_coef: 0.9173 - val_loss: 0.1000 - val_dice_coef: 0.9013
# Epoch 17/20
# 46/46 [==============================] - 10s 211ms/step - loss: 0.0804 - dice_coef: 0.9185 - val_loss: 0.2751 - val_dice_coef: 0.7283
# Epoch 18/20
# 46/46 [==============================] - 10s 212ms/step - loss: 0.0790 - dice_coef: 0.9197 - val_loss: 0.0949 - val_dice_coef: 0.9065
# Epoch 19/20
# 46/46 [==============================] - 10s 224ms/step - loss: 0.0763 - dice_coef: 0.9232 - val_loss: 0.1192 - val_dice_coef: 0.8823
# Epoch 20/20
# 46/46 [==============================] - 10s 224ms/step - loss: 0.0758 - dice_coef: 0.9245 - val_loss: 0.1156 - val_dice_coef: 0.8855
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
plotPredictions(X_train, y_train, X_valid, y_valid, X_test, y_test, model)
# Out:
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1018 - dice_coef: 0.8982
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1008 - dice_coef: 0.8992
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1470 - dice_coef: 0.8530

# %% [markdown]
# ## STEP 8: 마지막 모델 (U-Net)
# U-Net paper: https://arxiv.org/pdf/1505.04597.pdf
#
# skip connection으로 원본 영상을 최대한 살리는 방향으로 진행<br>
# **concatenation**
# ![대체 텍스트](https://www.renom.jp/notebooks/tutorial/image_processing/u-net/unet.png)

# %%
from tensorflow.keras.layers import Concatenate

def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPool2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPool2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPool2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPool2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    
    up6 = Concatenate()([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4])
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = BatchNormalization()(conv6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    
    up7 = Concatenate()([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3])
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)
    
    up8 = Concatenate()([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2])
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)
    
    up9 = Concatenate()([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1])
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
# build the model
model = unet()
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss=dice_coef_loss, optimizer=sgd, metrics=[dice_coef])

# fix random seed for reproductibility
seed = 7
np.random.seed(seed)
tf.random.set_seed(seed)

# FIT THE MODEL - OPTIMIZATION
hist = model.fit(X_train, y_train, validation_data=(X_valid, y_valid), epochs=20, batch_size=8, verbose=1)
model.save('unet.h5')

# 학습과정 살펴보기
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['dice_coef'], 'b', label='train dice_coef')
acc_ax.plot(hist.history['val_dice_coef'], 'g', label='val dice_coef')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('dice_coef')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/20
# 46/46 [==============================] - 17s 253ms/step - loss: 0.3699 - dice_coef: 0.6321 - val_loss: 0.6808 - val_dice_coef: 0.3207
# Epoch 2/20
# 46/46 [==============================] - 8s 177ms/step - loss: 0.1883 - dice_coef: 0.8140 - val_loss: 0.5005 - val_dice_coef: 0.5011
# Epoch 3/20
# 46/46 [==============================] - 8s 175ms/step - loss: 0.0871 - dice_coef: 0.9111 - val_loss: 0.3923 - val_dice_coef: 0.6087
# Epoch 4/20
# 46/46 [==============================] - 8s 175ms/step - loss: 0.0646 - dice_coef: 0.9282 - val_loss: 0.6569 - val_dice_coef: 0.3466
# Epoch 5/20
# 46/46 [==============================] - 8s 177ms/step - loss: 0.0995 - dice_coef: 0.9014 - val_loss: 0.5201 - val_dice_coef: 0.4821
# Epoch 6/20
# 46/46 [==============================] - 8s 176ms/step - loss: 0.0546 - dice_coef: 0.9459 - val_loss: 0.4671 - val_dice_coef: 0.5356
# Epoch 7/20
# 46/46 [==============================] - 8s 175ms/step - loss: 0.0499 - dice_coef: 0.9502 - val_loss: 0.3348 - val_dice_coef: 0.6664
# Epoch 8/20
# 46/46 [==============================] - 8s 177ms/step - loss: 0.0496 - dice_coef: 0.9494 - val_loss: 0.2955 - val_dice_coef: 0.7051
# Epoch 9/20
# 46/46 [==============================] - 8s 178ms/step - loss: 0.0452 - dice_coef: 0.9542 - val_loss: 0.3061 - val_dice_coef: 0.6966
# Epoch 10/20
# 46/46 [==============================] - 8s 177ms/step - loss: 0.0432 - dice_coef: 0.9564 - val_loss: 0.2799 - val_dice_coef: 0.7237
# Epoch 11/20
# 46/46 [==============================] - 8s 179ms/step - loss: 0.0421 - dice_coef: 0.9583 - val_loss: 0.0888 - val_dice_coef: 0.9127
# Epoch 12/20
# 46/46 [==============================] - 8s 178ms/step - loss: 0.0417 - dice_coef: 0.9578 - val_loss: 0.0635 - val_dice_coef: 0.9376
# Epoch 13/20
# 46/46 [==============================] - 8s 179ms/step - loss: 0.0403 - dice_coef: 0.9595 - val_loss: 0.0897 - val_dice_coef: 0.9125
# Epoch 14/20
# 46/46 [==============================] - 8s 177ms/step - loss: 0.0393 - dice_coef: 0.9608 - val_loss: 0.0517 - val_dice_coef: 0.9492
# Epoch 15/20
# 46/46 [==============================] - 8s 178ms/step - loss: 0.0386 - dice_coef: 0.9612 - val_loss: 0.0599 - val_dice_coef: 0.9413
# Epoch 16/20
# 46/46 [==============================] - 8s 178ms/step - loss: 0.0377 - dice_coef: 0.9627 - val_loss: 0.0514 - val_dice_coef: 0.9497
# Epoch 17/20
# 46/46 [==============================] - 8s 178ms/step - loss: 0.0372 - dice_coef: 0.9623 - val_loss: 0.0836 - val_dice_coef: 0.9173
# Epoch 18/20
# 46/46 [==============================] - 8s 178ms/step - loss: 0.0369 - dice_coef: 0.9617 - val_loss: 0.0452 - val_dice_coef: 0.9557
# Epoch 19/20
# 46/46 [==============================] - 8s 176ms/step - loss: 0.0358 - dice_coef: 0.9636 - val_loss: 0.0467 - val_dice_coef: 0.9542
# Epoch 20/20
# 46/46 [==============================] - 8s 176ms/step - loss: 0.0355 - dice_coef: 0.9645 - val_loss: 0.0451 - val_dice_coef: 0.9558

# %%
plotPredictions(X_train, y_train, X_valid, y_valid, X_test, y_test, model)
# Out:
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0243 - dice_coef: 0.9757
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0309 - dice_coef: 0.9691
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0333 - dice_coef: 0.9667
